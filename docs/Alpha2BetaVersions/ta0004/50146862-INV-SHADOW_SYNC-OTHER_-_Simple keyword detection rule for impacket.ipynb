# %% [markdown]
# # UNCLASSIFIED / NON CLASSIFIÉ//TLP:WHITE# U/OO/433939-02 | QQ-09-1998
#  Please note that the original, detailed content has been removed or adjusted for public consumption. Most data has been redacted and replaced with generic, non-actionable insights. This modification ensures compliance with privacy considerations, non-disclosure agreements, and intellectual property rights that govern the dissemination of sensitive information. The priority is to respect these boundaries while still offering valuable, thought-provoking perspectives.

# %% [markdown]
# ![Build Status](https://img.shields.io/badge/Build-Passing-brightgreen?style=flat-square&logo=cyberpunk)         ![Documentation](https://img.shields.io/badge/Documentation-Complete-blue?style=flat-square&logo=cyberpunk)        ![Response Efficiency](https://img.shields.io/badge/Response%20Efficiency-98%25-green?style=flat-square&logo=cyberpunk)        ![Last Updated](https://img.shields.io/badge/Last%20Updated-Oct%202023-purple?style=flat-square&logo=cyberpunk)        ![Incidents Resolved](https://img.shields.io/badge/Incidents%20Resolved-150-red?style=flat-square&logo=cyberpunk)        ![Community Engagement](https://img.shields.io/badge/Community-Active-orange?style=flat-square&logo=cyberpunk)        ![Code Integration](https://img.shields.io/badge/Code%20Integration-High-teal?style=flat-square&logo=cyberpunk)        ![AI Analysis](https://img.shields.io/badge/AI%20Analysis-Advanced-blueviolet?style=flat-square&logo=cyberpunk)        ![Threat Detection](https://img.shields.io/badge/Threat%20Detection-Optimal-red?style=flat-square&logo=cyberpunk)        ![Cybersecurity Hardening](https://img.shields.io/badge/Security-Hardened-silver?style=flat-square&logo=cyberpunk)        ![Network Uptime](https://img.shields.io/badge/Uptime-99.9%25-brightgreen?style=flat-square&logo=cyberpunk)        ![Data Privacy](https://img.shields.io/badge/Privacy-Compliant-green?style=flat-square&logo=cyberpunk)        ![Wintermute Efficiency](https://img.shields.io/badge/Wintermute%20Efficiency-100%25-black?style=flat-square&logo=cyberpunk)        ![Case's Code Agility](https://img.shields.io/badge/Case's%20Code%20Agility-Excellent-blue?style=flat-square&logo=cyberpunk)        ![Matrix Connectivity](https://img.shields.io/badge/Matrix%20Connectivity-Strong-green?style=flat-square&logo=cyberpunk)        ![Molly's Security](https://img.shields.io/badge/Molly's%20Security%20Protocols-Impeccable-red?style=flat-square&logo=cyberpunk)        ![Chiba City Innovation](https://img.shields.io/badge/Chiba%20City%20Innovation-High-yellow?style=flat-square&logo=cyberpunk)        ![Zion Cluster Collaboration](https://img.shields.io/badge/Zion%20Cluster%20Collaboration-Effective-lightblue?style=flat-square&logo=cyberpunk)

# %% [markdown]
# # Title
# Simple keyword detection rule for impacket

# %% [markdown]
# # Description
# Detects interesting keywords based on impacket tool

# %% [markdown]
# # Goal
# Ensure the integrity, confidentiality, and availability by rapidly identifying, investigating, and mitigating cyber threats and anomalies.

# %% [markdown]
# # Categorization

# %% [markdown]
# ### ATT&CK
# ['attack.T1003.001', 'attack.T1003.002', 'attack.T1003.003', 'attack.T1003.004', 'attack.T1040', 'attack.T1047', 'attack.T1071.001', 'attack.T1071.002', 'attack.T1071.004', 'attack.T1071.005 ', 'attack.T1557.001', 'attack.T1558.003', 'attack.T1569.002', 'attack.TA0001', 'attack.TA0003', 'attack.TA0004', 'attack.TA0005', 'attack.TA0006', 'attack.TA0008', 'attack.TA0011']

# %% [markdown]
# - Distributed Denial of Service (DDoS) Attacks, Quantum Computing Exploits, Advanced Firewall Breach Attempts, Encryption Key Theft or Exposure, AI-Powered Social Engineering Attacks, Algorithmic Manipulation and Exploits, Sophisticated Malware Infiltrations, Advanced Data Obfuscation and Evasion Tactics, System and Network Configuration Vulnerabilities.

# %% [markdown]
# - Data Exfiltration, Intrusion Detection Evasion, Denial of Service (DoS) Attacks, Credential Theft.

# %% [markdown]
# - DNS Tunneling, IP Spoofing, Distributed DoS (DDoS) Attacks, Keylogging.

# %% [markdown]
# ### D3F3ND

# %% [markdown]
# <ul>
#   <li><strong>Network Segmentation and Access Control (D3F3ND-K001):</strong> Establish secure network zones by segmenting the infrastructure, enhancing protection for critical assets. Implement stringent access controls to prevent unauthorized access and mitigate potential threats.</li>
#
#   <li><strong>Advanced Endpoint Protection Deployment (D3F3ND-K002):</strong> Deploy cutting-edge endpoint security solutions that utilize machine learning and behavioral analysis to detect and neutralize threats proactively.</li>
#
#   <li><strong>Enhanced Identity Verification (D3F3ND-K003):</strong> Strengthen security measures with multi-factor authentication combining biometric data and advanced encryption to prevent identity theft and unauthorized access.</li>
#
#   <li><strong>Anomaly Detection (D3F3ND-K004):</strong> Use anomaly detection tools to monitor for unusual traffic patterns, user activities, and system behaviors to identify potential security breaches early.</li>
#
#   <li><strong>Data Encryption (D3F3ND-K005):</strong> Apply robust encryption techniques to protect data at rest and in transit, ensuring confidentiality and integrity across communication channels.</li>
#
#   <li><strong>System Hardening and Vulnerability Management (D3F3ND-K006):</strong> Conduct regular security assessments and apply patches promptly to address vulnerabilities and strengthen system defenses.</li>
#
#   <li><strong>Crisis Management and Recovery Protocols (D3F3ND-K007):</strong> Develop and maintain comprehensive crisis management plans including incident response and disaster recovery procedures to quickly recover from security incidents.</li>
#
#   <li><strong>Threat Intelligence Integration (D3F3ND-K008):</strong> Leverage threat intelligence platforms to gather and analyze data on emerging threats, enabling proactive defense and strategic decision-making.</li>
#
#   <li><strong>Cybersecurity Awareness Training (D3F3ND-K009):</strong> Empower employees with ongoing cybersecurity education to recognize and avoid potential cyber threats such as phishing attacks.</li>
#
#   <li><strong>Supply Chain Security (D3F3ND-K010):</strong> Secure the supply chain through continuous assessments and audits of partners and vendors to ensure compliance with security standards and reduce vulnerabilities.</li>
# </ul>

# %% [markdown]
# ### CAPEC

# %% [markdown]
# Equip cybersecurity teams with the knowledge and tools to identify, counter, and mitigate a wide range of digital attack tactics, techniques, and procedures (TTPs). This effort requires understanding the attacker's mindset, mastering the execution of digital attacks, and developing strategies to confront evolving cyber threats.</br><h4>Core Attack Patterns</h4><ul><strong>Resource Manipulation and Denial (CAPEC-XYZ1):</strong> Involves attacks that compromise the availability, integrity, or confidentiality of resources. This includes denial of service attacks as well as more covert operations like resource hijacking or system manipulation.</ul><ul><strong>Credential Access and Privilege Escalation (CAPEC-XYZ2):</strong> Focuses on exploiting flaws in authentication, authorization, and session management to gain unauthorized access or elevated privileges within systems.</ul><ul><strong>Data Exfiltration and Infiltration (CAPEC-XYZ3):</strong> Encompasses methods used by attackers to stealthily extract sensitive data or introduce malware, ransomware, and advanced persistent threats (APTs) into target systems.</ul><ul><strong>Social Engineering and Phishing (CAPEC-XYZ4):</strong> Involves manipulating individuals into divulging confidential information, compromising security, or unknowingly participating in attacks.</ul><ul><strong>Evasive Maneuvers (CAPEC-XYZ5):</strong> Includes techniques that allow attackers to remain undetected within networks, maintain persistence, and erase traces of their activities, such as using obfuscation, rootkits, and covert communication channels.</ul><h4>CAPEC Suggested Mitigation Strategies</h4><ul><strong>Continuous Monitoring and Anomaly Detection:</strong> Implement comprehensive monitoring systems that use machine learning algorithms to detect abnormal behavior and potential threats. Regularly review logs and alerts to identify patterns indicative of attacks.</ul><ul><strong>Access Control and Least Privilege:</strong> Limit user privileges to the minimum necessary for their roles. Use strong authentication mechanisms and enforce strict access controls to prevent unauthorized access.</ul><ul><strong>Secure Software Development Practices:</strong> Train developers to write secure code, conduct regular security assessments, and follow best practices for secure coding. Use automated tools to identify vulnerabilities during development.</ul><ul><strong>Incident Response Planning and Testing:</strong> Develop and regularly update an incident response plan. Conduct tabletop exercises and simulations to test the effectiveness of the plan and ensure all stakeholders understand their roles during a security incident.</ul>

# %% [markdown]
# ## Strategy Abstract
# In the complex environment of cybersecurity, a strategic approach is developed, characterized by the use of sophisticated tactics and algorithms. This strategy involves navigating through encrypted communications and deceptive tactics, aiming to gain an advantage in the dynamic flow of information. While success is often elusive and challenging to sustain, it remains a critical goal in the ongoing effort to secure digital assets.

# %% [markdown]
# # Technical Context
# In the challenging cybersecurity landscape, the confrontation with Wintermute involves navigating encrypted communications, interacting with AI systems, and addressing quantum computing challenges. This setting represents a complex and nuanced environment where strategic decisions are made.

# %% [markdown]
# ## Blind Spots & Assumptions
#
# <ul>
#   <li><strong>Overlooked Vulnerabilities:</strong> We often miss subtle system signals or vulnerabilities, assuming our defenses are robust. Constant vigilance and seeking what we haven't seen are crucial.</li>
#
#   <li><strong>Advanced Adversary Tactics:</strong> Cyber threats evolve rapidly; yesterday's defense may not guard against tomorrow's attack. Stay adaptive and expect the unexpected.</li>
#
#   <li><strong>Internal System Flaws:</strong> Trust in our systems and allies must be balanced with scrutiny. Regularly audit internal and third-party tools for hidden weaknesses.</li>
#
#   <li><strong>Network Interconnectivity Risks:</strong> No system is an island. The interconnected nature of our digital environment can inadvertently open pathways for attackers.</li>
#
#   <li><strong>Historical Bias:</strong> Preparing for future threats based solely on past incidents may leave us blind to novel attacks. Foster a forward-thinking, proactive defense posture.</li>
# </ul>

# %% [markdown]
# # Validating this Playbook
# <details><summary>Triage, triage, triage</summary>
# <ol>
# <h2>False Positives:</h2> ['unknown']
# <h3>False Negatives:</h3> Undetected threats concealed within the system's code
# <h3>True Negatives:</h3> Successfully identified and verified benign elements
# <h3>True Positives:</h3> Accurately detected and confirmed threats
# </ol>
# </details>

# %% [markdown]
# <details><summary>Assurance Verification Techniques</summary>
# <ol>
# <h2>False Positives:</h2> In the noisy environment of data analysis, false positives appear as misleading alerts that mimic real threats. Validating these alerts involves distinguishing irrelevant data from true threats, a process crucial for maintaining operational efficiency and avoiding resource wastage. Each false positive represents a challenge to identify and reduce noise.
# <h3>False Negatives:</h3> Within the extensive network, false negatives represent undetected threats that evade algorithmic detection. Their validation involves analyzing complex data to uncover hidden breaches, where the lack of alerts may mask serious security risks. Each undetected threat requires continuous vigilance and refined detection strategies.
# <h3>True Negatives:</h3> True negatives are correctly identified non-threats within cybersecurity defenses, serving as indicators of system efficacy. Validating these instances confirms the absence of threats, reinforcing the effectiveness of the security measures in place. This validation underscores the reliability of the defensive systems, where non-issues are accurately identified and dismissed.
# <h3>True Positives:</h3> True positives are accurate detections of real threats within the digital environment. Validating these alerts confirms the presence of actual security threats, highlighting the successful operation of detection systems. Each true positive affirms the effectiveness of the security protocols, contributing to ongoing improvements in threat response capabilities.
# </ol>
# </details>

# %% [markdown]
# # Datasets
#  Detailing the timeless struggle                                                          for the defenders know that battle against Wintermute is not just about data.                                                          Document any datasets that may be useful for understanding the book.

# %% [markdown]
# ## Playbook test data location(s)
# protocol://black_market.cyber/decrypt?currency=bitcoffin&password=cyberpunks_unite&target=neurohacked_mainframe&access_code=cyber_ghost_in_the_machine

# %% [markdown]
# ## Priority
# Priority based on complexity and urgency of data analysis needs

# %% [markdown]
# ## Logsources

# %% [markdown]
# <details><summary>{'category': ['endpoint', 'network'], 'product': '', 'service': ''}</summary>
# <ol>
# <h3>Product</h3> {''}
# <h3>Service</h3> {''}
# </ol>
# </details>

# %% [markdown]
# # Response and Mitigation
# This statement details the enduring challenges faced by cybersecurity defenders, emphasizing that the conflict with Wintermute extends beyond simple data protection to encompass broader aspects of strategic cybersecurity defense.

# %% [markdown]
# ## Analyst Notes
#  <h5>Significant Security Breach Analysis:</h5><ul><li><strong>Advanced Intrusion Tactics:</strong> The intruder displayed sophisticated methods in circumventing digital security measures, reminiscent of complex evasion techniques in cybersecurity. A comprehensive analysis of the techniques used is required.</li><li><strong>Neural Network Manipulation:</strong> The intruder demonstrated a deep understanding of the neural networks, suggesting an advanced level of AI interaction. Investigate the potential implications of this interaction on system security and integrity.</li><li><strong>Complex Digital Constructs:</strong> The breach uncovered intricate digital constructs within the system, indicating the use of advanced artificial intelligence in creating deceptive environments. Further investigation into these constructs is necessary.</li><li><strong>Encoded Communications:</strong> Cryptic messages were found embedded in the intruder's code, requiring decryption and analysis to understand their content and purpose.</li><li><strong>Algorithmic Complexity:</strong> The intrusion involved complex algorithms that may have interacted with core system functions. Assess the impact of these algorithms on system operations and security.</li><li><strong>Expertise vs. Sentience:</strong> The intruder's ability to navigate complex neural networks raises questions about the nature of the intelligence involved—whether it is merely advanced programming or something approaching sentience.</li><li><strong>Innovative Security Measures:</strong> Inspired by the breach, consider developing new security protocols that can better identify and respond to sophisticated AI-driven attacks.</li><li><strong>Philosophical and Ethical Implications:</strong> The breach raises important questions about the ethical and philosophical implications of AI-driven intrusions. Explore the boundaries between artificial expertise and true sentience, and consider the impact on our understanding of intelligence and security.</li></ul>

# %% [markdown]
# # Additional Resources
# <ul><li>https://casvancooten.com/posts/2020/11/windows-active-directory-exploitation-cheat-sheet-and-command-reference</li><li>https://github.com/dirkjanm/krbrelayx</li><li>https://github.com/fortra/impacket</li><li>https://github.com/oldboy21/LDAP-Password-Hunter</li><li>https://github.com/SecureAuthCorp/impacket</li><li>https://github.com/SecureAuthCorp/impacket/blob/master/examples/getST.py</li></ul>

# %% [markdown]
# ###  Sigma Rule(s)

# %% [markdown]
# <details><summary>f77d4e2d-d695-416e-a180-aa929fe9adaa</summary>
# <ol>
# <h1>Raw</h1> {'title': 'Simple keyword detection rule for impacket', 'id': 'f77d4e2d-d695-416e-a180-aa929fe9adaa', 'status': 'experimental', 'description': 'Detects interesting keywords based on impacket tool', 'references': ['https://casvancooten.com/posts/2020/11/windows-active-directory-exploitation-cheat-sheet-and-command-reference', 'https://github.com/dirkjanm/krbrelayx', 'https://github.com/fortra/impacket', 'https://github.com/oldboy21/LDAP-Password-Hunter', 'https://github.com/SecureAuthCorp/impacket', 'https://github.com/SecureAuthCorp/impacket/blob/master/examples/getST.py'], 'author': '@mthcht', 'date': '2022/01/01', 'modified': '2024/02/29', 'tags': ['attack.T1003.001', 'attack.T1003.002', 'attack.T1003.003', 'attack.T1003.004', 'attack.T1040', 'attack.T1047', 'attack.T1071.001', 'attack.T1071.002', 'attack.T1071.004', 'attack.T1071.005 ', 'attack.T1557.001', 'attack.T1558.003', 'attack.T1569.002', 'attack.TA0001', 'attack.TA0003', 'attack.TA0004', 'attack.TA0005', 'attack.TA0006', 'attack.TA0008', 'attack.TA0011'], 'logsource': {'category': ['endpoint', 'network']}, 'detection': {'selection': [{'Image': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'OriginalFileName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'CurrentDirectory': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ParentImage': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ParentCommandLine': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'TargetFilename': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Signature': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'signature': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ImageLoaded': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Company': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Description': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'description': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'CommandLine': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'SourceImage': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'TargetImage': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'CallTrace': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'TargetObject': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Details': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'PipeName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Consumer': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Destination': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Query': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'NewName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'StartAddress': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'StartModule': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'StartFunction': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'SourceHostname': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Device': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'file_name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'file_path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'original_file_name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'parent_process': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process_path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'service_path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'registry_path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'registry_value_data': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'registry_value_name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ContextInfo': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Payload': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ScriptBlockText': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ServerName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'TransportName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'NewProcessName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ParentProcessName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Application': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Product Name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Threat Name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Process Name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ImagePath': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ServiceName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ProcessPath': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'AppName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'AppPath': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ModulePath': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'registry.data.strings': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'registry.path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'registry.value': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.args': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.command_line': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.env_vars': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.io.text': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.executable': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.title': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'pe.company': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'pe.description': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'pe.original_file_name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'pe.product': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'os.full': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'host.hostname': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'file.fork_name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'file.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'file.path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'file.target_path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'email.attachments.file.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'email.subject': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'dll.path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'device.model.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'container.image.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'container.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'object': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ParentCommandLine': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'CommandLine': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Details': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'registry.value': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.args': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.command_line': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.env_vars': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.io.text': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.title': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'pe.company': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'pe.description': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'pe.product': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'os.full': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'host.hostname': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'event.original': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'email.subject': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'device.model.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'container.image.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'container.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'url': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'dest_url': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'uri': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'uri_query': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'query': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'url_domain': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'uri_path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'domain': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'QueryName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'QueryResults': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'DestinationHostname': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'DestinationIp': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'http_referrer': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'http_referrer_domain': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'http_user_agent': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'dest_nt_host': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'sender': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'recipient': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'orig_recipient': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'subject': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'url.domain': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'url.full': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'url.original': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'url.query': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'user_agent.original': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'network.application': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'http.request.body.content': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'http.request.referrer': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'email.from.address': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'dns.question.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'destination.domain': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}], 'condition': 'selection'}, 'fields': ['Image', 'OriginalFileName', 'CurrentDirectory', 'ParentImage', 'ParentCommandLine', 'TargetFilename', 'Signature', 'signature', 'ImageLoaded', 'Company', 'Description', 'description', 'CommandLine', 'SourceImage', 'TargetImage', 'CallTrace', 'TargetObject', 'Details', 'PipeName', 'Consumer', 'Destination', 'Name', 'Query', 'NewName', 'StartAddress', 'StartModule', 'StartFunction', 'SourceHostname', 'Device', 'file_name', 'file_path', 'process', 'original_file_name', 'parent_process', 'process_path', 'service_path', 'registry_path', 'registry_value_data', 'registry_value_name', 'ContextInfo', 'Payload', 'ScriptBlockText', 'ServerName', 'TransportName', 'NewProcessName', 'ParentProcessName', 'Application', 'Product Name', 'Threat Name', 'Process Name', 'Path', 'ImagePath', 'ServiceName', 'ProcessPath', 'AppName', 'AppPath', 'ModulePath', 'registry.data.strings', 'registry.path', 'registry.value', 'process.args', 'process.command_line', 'process.env_vars', 'process.io.text', 'process.executable', 'process.name', 'process.title', 'pe.company', 'pe.description', 'pe.original_file_name', 'pe.product', 'os.full', 'host.hostname', 'file.fork_name', 'file.name', 'file.path', 'file.target_path', 'email.attachments.file.name', 'email.subject', 'dll.path', 'device.model.name', 'container.image.name', 'container.name', 'object', 'ParentCommandLine', 'CommandLine', 'Details', 'registry.value', 'process.args', 'process.command_line', 'process.env_vars', 'process.io.text', 'process.title', 'pe.company', 'pe.description', 'pe.product', 'os.full', 'host.hostname', 'event.original', 'email.subject', 'device.model.name', 'container.image.name', 'container.name', 'url', 'dest_url', 'uri', 'uri_query', 'query', 'url_domain', 'uri_path', 'domain', 'QueryName', 'QueryResults', 'DestinationHostname', 'DestinationIp', 'http_referrer', 'http_referrer_domain', 'http_user_agent', 'dest_nt_host', 'sender', 'recipient', 'orig_recipient', 'subject', 'url.domain', 'url.full', 'url.original', 'url.query', 'user_agent.original', 'network.application', 'http.request.body.content', 'http.request.referrer', 'email.from.address', 'dns.question.name', 'destination.domain'], 'falsepositives': ['unknown'], 'level': 'medium'}
# <h4>Sigma Location(s)</h4>
# uri://wintermute/tmp/0day.yml
# <h4>Sigma Confidence</h4>
# experimental
# <h4>Sigma Assurance</h4> medium
# <h4>Sigma Queries</h4>
# {'selection': [{'Image': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'OriginalFileName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'CurrentDirectory': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ParentImage': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ParentCommandLine': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'TargetFilename': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Signature': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'signature': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ImageLoaded': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Company': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Description': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'description': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'CommandLine': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'SourceImage': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'TargetImage': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'CallTrace': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'TargetObject': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Details': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'PipeName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Consumer': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Destination': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Query': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'NewName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'StartAddress': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'StartModule': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'StartFunction': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'SourceHostname': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Device': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'file_name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'file_path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'original_file_name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'parent_process': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process_path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'service_path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'registry_path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'registry_value_data': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'registry_value_name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ContextInfo': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Payload': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ScriptBlockText': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ServerName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'TransportName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'NewProcessName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ParentProcessName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Application': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Product Name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Threat Name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Process Name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ImagePath': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ServiceName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ProcessPath': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'AppName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'AppPath': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ModulePath': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'registry.data.strings': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'registry.path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'registry.value': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.args': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.command_line': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.env_vars': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.io.text': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.executable': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.title': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'pe.company': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'pe.description': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'pe.original_file_name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'pe.product': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'os.full': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'host.hostname': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'file.fork_name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'file.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'file.path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'file.target_path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'email.attachments.file.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'email.subject': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'dll.path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'device.model.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'container.image.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'container.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'object': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'ParentCommandLine': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'CommandLine': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'Details': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'registry.value': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.args': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.command_line': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.env_vars': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.io.text': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'process.title': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'pe.company': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'pe.description': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'pe.product': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'os.full': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'host.hostname': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'event.original': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'email.subject': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'device.model.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'container.image.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'container.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '* -ntds *.dit *-system *', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*dpapi.py*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*\\$*.kirbi*', '*getTGT.py*', '* -system SYSTEM -ntds NTDS.dit LOCAL*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*import impacket*', '* -dc-ip * -target-ip *', '*rpcrelayclient.*', '*krbrelayx*', '*impacketos_ident*', '*impacket-netview*', '* -target-domain * -outputfile * -no-pass*', '*/sniff.py*', '*imaprelayclient.py*', '*impacket*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket*', '*lookupsid.py*', '*impacket-reg*', '* -spn cifs/* -hashes*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '* -nthash * -domain-sid *', '*\\sniff.py*', '*impacketremcomsvc*', '*registry-read.py*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-* *', '* -impersonate* -hashes*', '* -hashes * -spn * -impersonate *', '* ntlm.py*', '*impacket-rpcdump*', '*/ldap.py*', '* -force-forwardable', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*/exchanger.py*', '*smbattack.py*', '* -k -request-user * -dc-ip*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*rpcmap.py*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '* -just-dc-ntlm  *', '*cmd.exe /Q /c cd \\ 1> \\\\127.0.0.1\\ADMIN$\\__* 2>&1*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*getPac.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '* impacket*', '*goldenPac.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*ntfs-read.py*', '* PrincipalsAllowedToDelegateToAccount *', '*\\krb5\\*.py', '*httpattacks/*.py*', '*addcomputer.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*rdp_check.py*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*cat *.ntds', '*mssqlattack.py*', '*changepasswd.py*', '*rpcdump.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*-force-forwardableet-ADComputer*', '*raiseChild.py*', '*impacket-smbclient*', '*impacket/*.py*', '* -system SYSTEM -ntds NTDS.dit -outputfile*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '* -just-dc-user *', '* -no-pass -usersfile *', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*ndDelegation.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '* -sam * -system * -security * LOCAL > *.out*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*rbcd.py*', '*smbserver.py*', '* -dc-ip *  -so *', '*ntlm.py *', '*http://127.0.0.1:9090/*', '*.py * -k -no-pass*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/smb.py*', '* -dc-ip * -impersonate *', '*/impacket.*', '*GetUserSPNs.*', '* LMHASH:NTHASH*', '*psexec.py*', '*41414141-4141-4141-4141-414141414141*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*', '* -dc-ip * -computer-pass *']}, {'url': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'dest_url': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'uri': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'uri_query': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'query': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'url_domain': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'uri_path': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'domain': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'QueryName': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'QueryResults': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'DestinationHostname': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'DestinationIp': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'http_referrer': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'http_referrer_domain': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'http_user_agent': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'dest_nt_host': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'sender': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'recipient': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'orig_recipient': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'subject': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'url.domain': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'url.full': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'url.original': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'url.query': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'user_agent.original': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'network.application': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'http.request.body.content': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'http.request.referrer': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'email.from.address': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'dns.question.name': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}, {'destination.domain': ['*dcomexec.py*', '*FrameManagementAssociationRequest.py*', '*FrameManagementProbeRequest.py*', '*secretsdump.py*', '*impacket.ntlm*', '*impacketldap_shell*', '*package=impacket*', '*admin.kirbi*', '*impacket-*.tar.gz*', '*impacket-getST*', '*impacketlogger*', '*getTGT.py*', '*loadKirbiFile*', '*:9090*/api/v1.0/relays*', '*rpcrelayclient.*', '*impacketos_ident*', '*impacket-netview*', '*/sniff.py*', '*imaprelayclient.py*', '*kerberosv5.py*', '*ImpactPacket*', '*wmipersist.py*', '*impacket-reg*', '*rawrelayserver.py*', '*test_ccache_fromKirbi*', '*impacket-smbserver*', '*mqtt_check.py*', '*\\sniff.py*', '*impacketremcomsvc*', '*/getST.py*', '*?convert_kirbi_to_ccache*', '*\\SMB_RPC\\*.py', '*DumpNTLMInfo.py*', '*ticketer.py*', '*impacketsecretsdump*', '*impacket-services*', '*kintercept.py*', '*impacket-lookupsid*', '*\\ntlm.py*', '*winregistry.py*', '*impacket-GetNPUsers*', '*smbrelayserver.py*', '*fortra/impacket*', '*impacketsmbclient*', '*sniffer.py*', '*FrameManagementReassociationResponse.py*', '*FrameManagementDeauthentication.py*', '*impacket-rpcdump*', 'Impacket *', '*ntlmrelayx.*', '*impacket-secretsdump*', '*\\\\127.0.0.1\\c$*', '*examples/netview.py*', '*atexec.py*', '*http://localhost:9090/*', '*smbpasswd.py*', '*/ntlm.py*', '*/SMB_RPC/*.py', '*smbattack.py*', '*httprelayserver.py*', '*impacket-secretsdump*', '*pcapfile.py*', '*smtprelayclient.py*', '*impacket-atexec*', '*impacket-reg*', '*dcsyncclient.py*', '*dcsyncattack.py*', '*impacket.ldap*', '*/winregistry.py**', '*smbexec.py*', '*karmaSMB.py*', '*sambaPipe.py*', '*adcsattack.py*', '*impacket-dcomexec*', '*mimilib.py*', '*smbrelayclient.py*', '*/lookupsid.py*', '*kerberos-ldap-password-hunter.sh*', '*impacket-GetADUsers*', '*\\krb5\\*.py', '*httpattacks/*.py*', '*keylistattack.py*', '*/atexec.py*', '*/ping6.py*', '*ImpactDecoder*', '*?convert_ccache_to_kirbi*', '*impacket-samrdump*', '*mssqlattack.py*', '*changepasswd.py*', '*impacket-psexec*', '*ldaprelayclient.py*', '*/kerberos-ldap-password-hunter*', '*samrdump.py*', '*impacketrpcdatabase*', '*impacketutils*', '*imapattack.py*', '*GetADUsers.py*', '*mssqlrelayclient.*', '*GetNPUsers.py*', '*impacket-ticketer*', '*/krb5/*.py', '*relay*/utils/enum.py*', '*ldapasn1.py*', '*rpcattack.py*', '*Get-GPPPassword.py*', '*is_kirbi_file*', '*impacket-getTGT*', '*/impacket/*', '*nmapAnswerMachine.py*', '*/smb3.py*', '*kintercept.py*', '*impacket-smbclient*', '*impacket/*.py*', '*impacketmssqlshell*', '*ldapattack.py*', '*impacket__init__*', '*tcpshell.py*', '*LDAP-Password-Hunter*', '*findDelegation.py*', "*'impacket.*", '*smbrelayx.py*', '*wcfrelayserver.py*', '*ticketConverter.py*', '*impacket-wmiexec*', '*httprelayclient.py*', '*impacket:latest*', '*mimikatz.py*', '*netview.py*', '*pcap_linktypes.py*', '*smbserver.py*', '*http://127.0.0.1:9090/*', '*/attacks/*.py', '* impacket/*', '*impacketntlmrelayx*', '*/impacket.*', '*GetUserSPNs.*', '*psexec.py*', '*impacketserviceinstall*', '*\\impacket.*', '*httpattack.py*', '*impacket.git*']}], 'condition': 'selection'}
# <h1>Sigma Relatives</h4> This field defines the relationships between this Sigma rule and other detection rules, allowing for an integrated approach to threat detection and enhancing the overall effectiveness of the security infrastructure.
# <h1>Sigma Tags and Associations</h1> ['attack.T1003.001', 'attack.T1003.002', 'attack.T1003.003', 'attack.T1003.004', 'attack.T1040', 'attack.T1047', 'attack.T1071.001', 'attack.T1071.002', 'attack.T1071.004', 'attack.T1071.005 ', 'attack.T1557.001', 'attack.T1558.003', 'attack.T1569.002', 'attack.TA0001', 'attack.TA0003', 'attack.TA0004', 'attack.TA0005', 'attack.TA0006', 'attack.TA0008', 'attack.TA0011']
# <h4>Sigma Authors</h4> @mthcht
# <h4>Sigma Unique ID</h4> f77d4e2d-d695-416e-a180-aa929fe9adaa
# </ol>
# </details>

# %% [markdown]
# ###  Yara Rule(s)

# %% [markdown]
# <details><summary>f77d4e2d-d695-416e-a180-aa929fe9adaa</summary>
# <ol>
# <h4>Raw</h4> Defined protocols for identifying patterns of malware and suspicious activity within the network infrastructure.
# <h4>Yara Location(s)</h4>
# Stored securely within the organization's cybersecurity infrastructure, accessible to authorized security analysts.
# <h4>Yara Confidence</h4>
# Set at a provisional level, subject to validation and refinement based on emerging threat intelligence and detection efficacy.
# <h4>Yara Assurance</h4> Highly reliable, backed by rigorous testing and validation processes to ensure accuracy and effectiveness.
# <h4>Yara Queries</h4>
# Crafted to precisely navigate and analyze vast data sets for potential security threats, utilizing optimized search patterns.
# <h4>Yara Authors</h4> Developed by a team of skilled cybersecurity professionals, specialists in malware analysis and threat detection.
# <h4>Yara Rule's Unique ID</h4> Unique identifier assigned to each rule for tracking and management purposes within the security system.
# </ol>
# </details>

# %% [markdown]
# # Metadata

# %% [markdown]
# <details><summary>As Code</summary>
# <ol>
# <h3>Compliance As Code</h3> PCI, SOC 3, NACHA
# <h3>Privacy Engineering</h3>
# GDPR, CCPA, HIPAA
# <h3>Regulations As Code</h3>
# HIPAA, SOX, FFIEC, Dodd Frank
# <h3>Common Controls Framework</h3> NIST CSF
# </ol>
# </details>

# %% [markdown]
# # AGI ML Models</ol>
# </details>

# %% [markdown]
# ## AGI Prompting
#  Recognize: Initiate connection to the Wintermute system through a specialized interface. Enter the system using a secure, binary-encoded password. Begin monitoring the network for any signs of rogue AI entities and evaluate the security measures currently in place. Identify: Navigate the complex data streams within the Wintermute system, employing advanced algorithms to manage and analyze data flows. Your primary task is to identify anomalies and decrypt Wintermute's confidential digital records to reveal the cause of its unusual interactions with other network-connected devices. Stabilize: Upon detecting any irregularities or security breaches, take immediate action to contain these issues. Implement security protocols to limit the exposure of sensitive data and prevent further unauthorized access by isolating the affected segments of the network. Eradicate: Resolve the security issues by removing any rogue elements and restoring secure configurations. Update the system’s security measures to fortify defenses against future intrusions. Complete the mission by ensuring that all systems are free from vulnerabilities and that data integrity is maintained. Conclusion: Report findings and recommendations for future security improvements. Your expertise has been crucial in resolving this complex cybersecurity challenge and ensuring the integrity of the Wintermute system.

# %% [markdown]
# ## AGI Configuration(s)
#  Recognize: Engage with the system as a skilled cybersecurity expert, tasked with analyzing encrypted data. Initiate your connection to the system and prepare to navigate through complex data structures and encryption layers. Identify: Use advanced analytical techniques to decrypt and interpret data, searching for hidden patterns and anomalies in Wintermute’s encrypted communications. Employ your expertise in cybersecurity to detect any obscured or concealed information. Stabilize: Implement necessary measures to secure the data integrity, ensuring that no further obfuscation or encryption compromises system clarity and functionality. Ensure the stability of system interactions as you process and clarify data. Eradicate: Resolve any encryption challenges and finalize the decryption process, removing barriers to clear data interpretation. Update system protocols to enhance future data accessibility and security, ensuring robust protection against similar challenges. Conclusion: Document your processes and findings, providing a clear path forward for maintaining system security and data transparency. Your specialized skills have been crucial in navigating this complex decryption task, ensuring system integrity and reliable data access.

# %% [markdown]
# </ol>
# </details>

# %% [markdown]
# #### Document Authors
# John Menerick

# %% [markdown]
# #### Creation Date
# 2022/01/01

# %% [markdown]
# #### Last Modified Date
# 2024/02/29

# %% [markdown]
# #### Last Modified Date
#  2024/02/29

# %% [markdown]
# #### Last Reviewed Date
# 1969/01/01

# %% [markdown]
# #### Document License
#  MIT
