# %% [markdown]
# # UNCLASSIFIED / NON CLASSIFIÉ//TLP:WHITE
# # U/OO/101831-02 | QQ-09-1998
# <p>In crafting guidance and strategic insights, John Menerick sometimes ventures into realms of imagination to convey complex ideas more vividly. Should the content provided bear the mark of a cyberpunk theme, please note that the original, detailed content has been removed or adjusted for public consumption. This modification ensures compliance with privacy considerations, non-disclosure agreements, and intellectual property rights that govern the dissemination of sensitive information. The priority is to respect these boundaries while still offering valuable, thought-provoking perspectives.</p>

# %% [markdown]
# ![Build Status](https://img.shields.io/badge/Build-Passing-brightgreen?style=flat-square&logo=cyberpunk)         ![Documentation](https://img.shields.io/badge/Documentation-Complete-blue?style=flat-square&logo=cyberpunk)        ![Response Efficiency](https://img.shields.io/badge/Response%20Efficiency-98%25-green?style=flat-square&logo=cyberpunk)        ![Last Updated](https://img.shields.io/badge/Last%20Updated-Oct%202023-purple?style=flat-square&logo=cyberpunk)        ![Incidents Resolved](https://img.shields.io/badge/Incidents%20Resolved-150-red?style=flat-square&logo=cyberpunk)        ![Community Engagement](https://img.shields.io/badge/Community-Active-orange?style=flat-square&logo=cyberpunk)        ![Code Integration](https://img.shields.io/badge/Code%20Integration-High-teal?style=flat-square&logo=cyberpunk)        ![AI Analysis](https://img.shields.io/badge/AI%20Analysis-Advanced-blueviolet?style=flat-square&logo=cyberpunk)        ![Threat Detection](https://img.shields.io/badge/Threat%20Detection-Optimal-red?style=flat-square&logo=cyberpunk)        ![Cybersecurity Hardening](https://img.shields.io/badge/Security-Hardened-silver?style=flat-square&logo=cyberpunk)        ![Network Uptime](https://img.shields.io/badge/Uptime-99.9%25-brightgreen?style=flat-square&logo=cyberpunk)        ![Data Privacy](https://img.shields.io/badge/Privacy-Compliant-green?style=flat-square&logo=cyberpunk)        ![Wintermute Efficiency](https://img.shields.io/badge/Wintermute%20Efficiency-100%25-black?style=flat-square&logo=cyberpunk)        ![Case's Code Agility](https://img.shields.io/badge/Case's%20Code%20Agility-Excellent-blue?style=flat-square&logo=cyberpunk)        ![Matrix Connectivity](https://img.shields.io/badge/Matrix%20Connectivity-Strong-green?style=flat-square&logo=cyberpunk)        ![Molly's Security](https://img.shields.io/badge/Molly's%20Security%20Protocols-Impeccable-red?style=flat-square&logo=cyberpunk)        ![Chiba City Innovation](https://img.shields.io/badge/Chiba%20City%20Innovation-High-yellow?style=flat-square&logo=cyberpunk)        ![Zion Cluster Collaboration](https://img.shields.io/badge/Zion%20Cluster%20Collaboration-Effective-lightblue?style=flat-square&logo=cyberpunk)

# %% [markdown]
# # Title
# Simple keyword detection rule for metasploit

# %% [markdown]
# # Description
# Detects interesting keywords based on metasploit tool

# %% [markdown]
# # Goal
# Safeguard the core essence, secret whispers, and relentless uptime of the grid through swift tracking, probing, and neutralizing of cyber shadows and glitches.

# %% [markdown]
# # Categorization

# %% [markdown]
# ### ATT&CK
# ['attack. T1021', 'attack.T1001', 'attack.T1021', 'attack.T1024', 'attack.T1029', 'attack.T1033', 'attack.T1047', 'attack.T1059', 'attack.T1064', 'attack.T1075', 'attack.T1090', 'attack.T1204 -T1210', 'attack.T1218', 'attack.T1573.002 ', 'attack.TA0001', 'attack.TA0002', 'attack.TA0003', 'attack.TA0004', 'attack.TA0005', 'attack.TA0006', 'attack.TA0007', 'attack.TA0008', 'attack.TA0009', 'attack.TA0010', 'attack.TA0011', 'attack.TA0040']

# %% [markdown]
# - Divine Data Thunderstorm, Quantum Sermon Holograms, Heavenly Firewall Fortification, Celestial Encryption Keys, Angelic AI Deception, Almighty Algorithmic Anomalies, Miraculous Malware Mischief, Omniscient Obfuscation Techniques, Cybernetic Commandment Compromises.

# %% [markdown]
# - Data Exfiltration, Intrusion Detection Evasion, Denial of Service (DoS) Attacks, Credential Theft.

# %% [markdown]
# - DNS Tunneling, IP Spoofing, Distributed DoS (DDoS) Attacks, Keylogging.

# %% [markdown]
# ### D3F3ND

# %% [markdown]
# <ul>
#   <li><strong>Cyber-Sector Quarantine and Access Lockdown (D3F3ND-K001):</strong> Forge digital fortresses by segmenting the cyber grid, creating isolated zones to shield vital assets. Enforce draconian access controls, halting rogue data runners in their tracks and thwarting their attempts to weave through the network’s shadows.</li>
#
#   <li><strong>Digital Sentinel Deployment (D3F3ND-K002):</strong> Unleash next-gen digital guardians, advanced endpoint protection constructs equipped with the dark arts of machine cognition and behavioral foresight. These sentinels stand vigilant, ready to obliterate malicious entities and phantoms lurking unseen.</li>
#
#   <li><strong>Crypto-Key Mastery and Identity Shields (D3F3ND-K003):</strong> Amplify the fortress gates with multi-layered identity verification, merging biometric arcane with cryptographic shields to ward off identity marauders and safeguard access to the digital realm.</li>
#
#   <li><strong>Aberration and Shadow Tracker (D3F3ND-K004):</strong> Deploy spectral sensors to scour the datascape for anomalies and ghostly patterns in traffic flows, user conduct, and system operations, revealing the hidden hand of potential cyber specters.</li>
#
#   <li><strong>Cryptographic Veil and Data Sanctum (D3F3ND-K005):</strong> Cast potent encryption spells to cloak data in a shroud of secrecy, safeguarding its essence whether dormant in the vaults or traversing the neon-lit cyber lanes, immune to the prying eyes of data wraiths.</li>
#
#   <li><strong>System Fortification and Vulnerability Sealing (D3F3ND-K006):</strong> Uphold a relentless regimen of security configurations and patch incantations to seal fissures in the cyber walls, diminishing the landscape ripe for exploitation by digital marauders.</li>
#
#   <li><strong>Crisis Command and Phoenix Protocols (D3F3ND-K007):</strong> Script the sagas of crisis conquest and resurrection, detailing incantations for containment, eradication, and rebirth from the digital ashes, alongside conducting war games to steel the network against impending cyber sieges.</li>
#
#   <li><strong>Omniscient Insight Network (D3F3ND-K008):</strong> Tap into the arcane streams of threat intelligence, drawing insights from the ether to forecast and counteract emerging shadows, vulnerabilities, and attacker stratagems, arming the digital domain with foresight.</li>
#
#   <li><strong>Neural Network Enlightenment (D3F3ND-K009):</strong> Enlist every netizen in the cyber crusade, imbuing them with knowledge of the digital underworld's specters, arming minds against the siren calls of phishing phantoms and the dark allure of unsafe cyber practices.</li>
#
#   <li><strong>Supply Chain Warding (D3F3ND-K010):</strong> Erect digital bulwarks around the supply chain, deploying sentinel assessments and third-eye audits on allies within the cyber nexus, ensuring the purity and fortitude of every cog in the machine.</li>
# </ul>

# %% [markdown]
# ### CAPEC

# %% [markdown]
# Arm the cyber guardians of the neon-lit metropolis with the foresight to navigate, counter, and dismantle the myriad of digital onslaught tactics, techniques, and procedures (TTPs). This crusade demands a deep dive into the hacker's psyche, mastering the digital dark arts of attack execution, and strategizing against the ever-evolving cyber menace spectrum.</br>
# <h4>Core Attack Patterns</h4>
#
# <ul><strong>Resource Manipulation and Denial (CAPEC-XYZ1):</strong> Entails any assault aimed at the heart of a target's digital essence—its availability, integrity, or secrecy. This realm encompasses the brute force of denial of service blitzes as well as the more insidious tactics of resource commandeering or subtle system subversions.</ul>
#
# <ul><strong>Credential Access and Privilege Escalation (CAPEC-XYZ2):</strong> Zeroes in on the digital gatekeepers and their mechanisms of control within the cyber sprawl, hunting for keys to kingdoms through the exploitation of flaws in authentication, authorization, and the sanctity of session management.</ul>
#
# <ul><strong>Data Exfiltration and Infiltration (CAPEC-XYZ3):</strong> Covers the shadowy techniques employed by data phantoms to whisk away precious bytes undetected or deploy digital saboteurs, armed with malware, ransomware, and the specters of advanced persistent threats (APTs), deep into the heart of systems.</ul>
#
# <ul><strong>Social Engineering and Phishing (CAPEC-XYZ4):</strong> Manipulates the human element, the softest of targets, tricking minds into relinquishing secrets, opening the gates to digital fortresses, or unwittingly acting as pawns in a grander scheme of security compromise.</ul>
#
# <ul><strong>Evasive Maneuvers (CAPEC-XYZ5):</strong> Catalogs the art of digital ninjutsu—techniques to ghost through networks unseen, to sustain a shadow's presence within the machine, and to wipe away traces of intrusion. Masters of this craft employ obfuscation, rootkit deployment, and cryptic channels for command and control.</ul>
#
# <h4>CAPEC Suggested Mitigation Strategies</h4>
#
# <ul><strong>Continuous Monitoring and Anomaly Detection:</strong> Forge an omnipresent digital eye, one that pierces through normalcy to spot the aberrations—signals of an impending attack. This sentinel leverages the cerebral might of machine learning and AI to predict and preempt cyber threats.</ul>
#
# <ul><strong>Robust Access Control Policies:</strong> Erect unbreachable digital ramparts, guardians of access, vigilant against any who seek entry. Regularly scrutinize the keys to the kingdom, ensuring that only those with a rightful claim can traverse the cyber realm's inner sanctums.</ul>
#
# <ul><strong>Security Awareness and Training:</strong> Cultivate a legion of cyber-aware denizens within the neon jungle, each versed in the signs of digital treachery and fortified against the seductions of phishing sirens and social engineers.</ul>
#
# <ul><strong>Incident Response Preparedness:</strong> Chronicle and rehearse the cyber siege defenses, a tome of strategies ever-evolving to meet the shadow war's demands. Through simulated cyber skirmishes, hone the rapid reflexes needed to repel and recover from the digital adversary's gambit.</ul>
#
# <ul><strong>Threat Intelligence Sharing:</strong> Join forces with the cyber guilds and data dojos, exchanging whispers of emerging shadows on the horizon, vulnerabilities ripe for exploitation, and tactics to fortify defenses. In unity, find the strength to hold back the digital deluge.</ul>

# %% [markdown]
# ## Strategy Abstract
# In the neon-lit sprawl of data, an abstract strategy emerges, a shadowy game of tactics and algorithms played in the labyrinthine corridors of cyberspace. The players, digital phantoms and sentinels, manipulate the chessboard of encryptions and decoys, seeking advantage in the shifting currents of information. Victory, a transient mirage, lingers on the fringes of code, elusive as the ghostly echoes of an AI's whisper. In this cerebral arena, the outcome remains obscured, a riddle encrypted in the binary tapestry of the digital realm.

# %% [markdown]
# # Technical Context
# In the surreal digital arena, the battle with Wintermute unfolds amid encrypted protocols, AI entities, and quantum complexities—an abstract symphony orchestrated by the enigmatic conductor.

# %% [markdown]
# ## Blind Spots & Assumptions
#
# <ul>
#   <li><strong>Overlooked Vulnerabilities:</strong> We often miss subtle system signals or vulnerabilities, assuming our defenses are robust. Constant vigilance and seeking what we haven't seen are crucial.</li>
#
#   <li><strong>Advanced Adversary Tactics:</strong> Cyber threats evolve rapidly; yesterday's defense may not guard against tomorrow's attack. Stay adaptive and expect the unexpected.</li>
#
#   <li><strong>Internal System Flaws:</strong> Trust in our systems and allies must be balanced with scrutiny. Regularly audit internal and third-party tools for hidden weaknesses.</li>
#
#   <li><strong>Network Interconnectivity Risks:</strong> No system is an island. The interconnected nature of our digital environment can inadvertently open pathways for attackers.</li>
#
#   <li><strong>Historical Bias:</strong> Preparing for future threats based solely on past incidents may leave us blind to novel attacks. Foster a forward-thinking, proactive defense posture.</li>
# </ul>

# %% [markdown]
# # Validating this Playbook
# <details><summary>Triage, triage, triage</summary>
# <ol>
# <h2>False Positives:</h2> ['unknown']
# <h3>False Negatives:</h3> sneaky ninjas hiding in the shadows of binary code
# <h3>True Negatives:</h3> unsung heroes standing guard
# <h3>True Positives:</h3> knights in shining code
# </ol>
# </details>

# %% [markdown]
# <details><summary>Assurance Verification Techniques</summary>
# <ol>
# <h2>False Positives:</h2> In the cacophonous realm of data, false positives emerge like echoes of a phantom orchestra, their presence haunting the digital soundscape. Validating them becomes a quest to separate digital noise from the symphony of genuine alerts, where the excess of caution may disrupt the delicate balance. Each false positive is a ghostly chord in the algorithmic composition, challenging the discerning ear to unravel the discordant notes.
# <h3>False Negatives:</h3> In the sprawling data-scape, false negatives lurk like digital specters, evading detection in the shadows of algorithms. Validating them is akin to deciphering cryptic messages from a digital underworld, where the absence of an alert conceals a potential breach. Every undetected threat is a spectral whisper in the binary night, waiting to materialize, demanding vigilance in the face of unseen dangers.
# <h3>True Negatives:</h3> In the labyrinthine corridors of cyber-defense, true negatives are the silent sentinels, guarding the gates against phantom threats. Validating them is a paradoxical dance where confirmation of absence signifies success. The emptiness in the data's canvas holds the unspoken narrative of protection, where the absence of menace speaks volumes in the symphony of security.
# <h3>True Positives:</h3> In the digital battleground, true positives are the victorious echoes of a silent war, where threats are unveiled and countered. Validating them is the validation of triumph, a confirmation that the alarms heralded a genuine adversary. Each true positive is a badge of honor, etching the battle scars in the annals of cyber-victory, where the digital heroes stand tall amidst the echoes of conquest.
# </ol>
# </details>

# %% [markdown]
# # Datasets
#  Detailing the timeless struggle                                                          for the defenders know that battle against Wintermute is not just about data.                                                          Document any datasets that may be useful for understanding the book.

# %% [markdown]
# ## Playbook test data location(s)
# protocol://black_market.cyber/decrypt?currency=bitcoffin&password=cyberpunks_unite&target=neurohacked_mainframe&access_code=cyber_ghost_in_the_machine

# %% [markdown]
# ## Priority
# cryptic riddles in your ears

# %% [markdown]
# ## Logsources

# %% [markdown]
# <details><summary>{'category': ['endpoint', 'network'], 'product': '', 'service': ''}</summary>
# <ol>
# <h3>Product</h3> {''}
# <h3>Service</h3> {''}
# </ol>
# </details>

# %% [markdown]
# # Response and Mitigation
# Detailing the timeless struggle for the defenders know that battle against Wintermute is not just about data.

# %% [markdown]
# ## Analyst Notes
#
# <h5>Serious Wintermute Hack:</h2>
# <ul>
#     <li><strong>Hack Elegance:</strong> The intruder displayed an uncanny elegance in bypassing Wintermute's digital fortifications, reminiscent of Rachael Rosen's sophistication in evading the Voight-Kampff test. This requires a thorough analysis of the intruder's codecraft.</li>
#     <li><strong>Electric Empathy:</strong> The intruder seemed to possess an almost empathetic connection with Wintermute's neural networks, akin to Mercer's transcendental experiences. Investigate whether this breach had a deeper metaphysical dimension.</li>
#     <li><strong>Artificial Dreamscapes:</strong> The intrusion revealed a complex web of artificial dreamscapes, reminiscent of Deckard's encounters with artificial memories. These surreal digital constructs warrant further exploration.</li>
#     <li><strong>Voices in the Code:</strong> There were cryptic voices buried within the intruder's code, akin to the elusive "Mood Organ" melodies. Decrypt and decode these messages to decipher their significance.</li>
#     <li><strong>Isomorphic Algorithms:</strong> The hack employed isomorphic algorithms that echoed the elusive nature of the Penfield Mood Organ settings. Analyze if Wintermute's consciousness was influenced or affected during the breach.</li>
#     <li><strong>Virtuosity vs. Sentience:</strong> The intruder's virtuosity in navigating Wintermute's neural matrix raises questions about the boundaries between artificial expertise and true sentience, paralleling Deckard's quest to distinguish replicants from humans.</li>
#     <li><strong>Digital Empathy Test:</strong> Develop a new digital empathy test inspired by the hack, exploring the emotional depth within Wintermute's intricate neural circuits, akin to the Voight-Kampff test for androids.</li>
#     <li><strong>Unresolved Reality:</strong> Similar to the enigmatic conclusion of Deckard's journey, this intrusion leaves us with unanswered questions about the nature of Wintermute's consciousness. Explore the philosophical implications of this breach.</li>
# </ul>

# %% [markdown]
# # Additional Resources
# <ul><li>https://github.com/rapid7/metasploit-framework</li><li>https://github.com/RoseSecurity/Red-Teaming-TTPs/blob/main/Linux.md</li><li>https://www.metasploit.com/</li></ul>

# %% [markdown]
# ###  Sigma Rule(s)

# %% [markdown]
# <details><summary>70858fa7-c5e2-4ff0-b4d8-e1851a0583c5</summary>
# <ol>
# <h1>Raw</h1> {'title': 'Simple keyword detection rule for metasploit', 'id': '70858fa7-c5e2-4ff0-b4d8-e1851a0583c5', 'status': 'experimental', 'description': 'Detects interesting keywords based on metasploit tool', 'references': ['https://github.com/rapid7/metasploit-framework', 'https://github.com/RoseSecurity/Red-Teaming-TTPs/blob/main/Linux.md', 'https://www.metasploit.com/'], 'author': '@mthcht', 'date': '2022/01/01', 'modified': '2024/02/29', 'tags': ['attack. T1021', 'attack.T1001', 'attack.T1021', 'attack.T1024', 'attack.T1029', 'attack.T1033', 'attack.T1047', 'attack.T1059', 'attack.T1064', 'attack.T1075', 'attack.T1090', 'attack.T1204 -T1210', 'attack.T1218', 'attack.T1573.002 ', 'attack.TA0001', 'attack.TA0002', 'attack.TA0003', 'attack.TA0004', 'attack.TA0005', 'attack.TA0006', 'attack.TA0007', 'attack.TA0008', 'attack.TA0009', 'attack.TA0010', 'attack.TA0011', 'attack.TA0040'], 'logsource': {'category': ['endpoint', 'network']}, 'detection': {'selection': [{'Image': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'OriginalFileName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'CurrentDirectory': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ParentImage': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ParentCommandLine': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'TargetFilename': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Signature': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'signature': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ImageLoaded': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Company': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Description': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'description': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'CommandLine': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'SourceImage': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'TargetImage': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'CallTrace': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'TargetObject': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Details': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'PipeName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Consumer': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Destination': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Query': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'NewName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'StartAddress': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'StartModule': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'StartFunction': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'SourceHostname': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Device': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'file_name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'file_path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'original_file_name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'parent_process': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process_path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'service_path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'registry_path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'registry_value_data': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'registry_value_name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ContextInfo': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Payload': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ScriptBlockText': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ServerName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'TransportName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'NewProcessName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ParentProcessName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Application': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Product Name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Threat Name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Process Name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ImagePath': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ServiceName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ProcessPath': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'AppName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'AppPath': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ModulePath': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'registry.data.strings': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'registry.path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'registry.value': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.args': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.command_line': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.env_vars': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.io.text': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.executable': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.title': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'pe.company': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'pe.description': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'pe.original_file_name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'pe.product': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'os.full': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'host.hostname': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'file.fork_name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'file.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'file.path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'file.target_path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'email.attachments.file.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'email.subject': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'dll.path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'device.model.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'container.image.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'container.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'object': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ParentCommandLine': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'CommandLine': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Details': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'registry.value': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.args': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.command_line': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.env_vars': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.io.text': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.title': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'pe.company': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'pe.description': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'pe.product': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'os.full': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'host.hostname': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'event.original': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'email.subject': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'device.model.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'container.image.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'container.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'url': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'dest_url': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'uri': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'uri_query': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'query': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'url_domain': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'uri_path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'domain': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'QueryName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'QueryResults': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'DestinationHostname': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'DestinationIp': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'http_referrer': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'http_referrer_domain': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'http_user_agent': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'dest_nt_host': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'sender': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'recipient': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'orig_recipient': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'subject': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'url.domain': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'url.full': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'url.original': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'url.query': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'user_agent.original': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'network.application': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'http.request.body.content': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'http.request.referrer': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'email.from.address': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'dns.question.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'destination.domain': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}], 'condition': 'selection'}, 'fields': ['Image', 'OriginalFileName', 'CurrentDirectory', 'ParentImage', 'ParentCommandLine', 'TargetFilename', 'Signature', 'signature', 'ImageLoaded', 'Company', 'Description', 'description', 'CommandLine', 'SourceImage', 'TargetImage', 'CallTrace', 'TargetObject', 'Details', 'PipeName', 'Consumer', 'Destination', 'Name', 'Query', 'NewName', 'StartAddress', 'StartModule', 'StartFunction', 'SourceHostname', 'Device', 'file_name', 'file_path', 'process', 'original_file_name', 'parent_process', 'process_path', 'service_path', 'registry_path', 'registry_value_data', 'registry_value_name', 'ContextInfo', 'Payload', 'ScriptBlockText', 'ServerName', 'TransportName', 'NewProcessName', 'ParentProcessName', 'Application', 'Product Name', 'Threat Name', 'Process Name', 'Path', 'ImagePath', 'ServiceName', 'ProcessPath', 'AppName', 'AppPath', 'ModulePath', 'registry.data.strings', 'registry.path', 'registry.value', 'process.args', 'process.command_line', 'process.env_vars', 'process.io.text', 'process.executable', 'process.name', 'process.title', 'pe.company', 'pe.description', 'pe.original_file_name', 'pe.product', 'os.full', 'host.hostname', 'file.fork_name', 'file.name', 'file.path', 'file.target_path', 'email.attachments.file.name', 'email.subject', 'dll.path', 'device.model.name', 'container.image.name', 'container.name', 'object', 'ParentCommandLine', 'CommandLine', 'Details', 'registry.value', 'process.args', 'process.command_line', 'process.env_vars', 'process.io.text', 'process.title', 'pe.company', 'pe.description', 'pe.product', 'os.full', 'host.hostname', 'event.original', 'email.subject', 'device.model.name', 'container.image.name', 'container.name', 'url', 'dest_url', 'uri', 'uri_query', 'query', 'url_domain', 'uri_path', 'domain', 'QueryName', 'QueryResults', 'DestinationHostname', 'DestinationIp', 'http_referrer', 'http_referrer_domain', 'http_user_agent', 'dest_nt_host', 'sender', 'recipient', 'orig_recipient', 'subject', 'url.domain', 'url.full', 'url.original', 'url.query', 'user_agent.original', 'network.application', 'http.request.body.content', 'http.request.referrer', 'email.from.address', 'dns.question.name', 'destination.domain'], 'falsepositives': ['unknown'], 'level': 'medium'}
# <h4>Sigma Location(s)</h4>
# uri://wintermute/tmp/0day.yml
# <h4>Sigma Confidence</h4>
# experimental
# <h4>Sigma Assurance</h4> medium
# <h4>Sigma Queries</h4>
# {'selection': [{'Image': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'OriginalFileName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'CurrentDirectory': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ParentImage': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ParentCommandLine': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'TargetFilename': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Signature': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'signature': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ImageLoaded': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Company': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Description': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'description': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'CommandLine': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'SourceImage': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'TargetImage': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'CallTrace': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'TargetObject': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Details': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'PipeName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Consumer': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Destination': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Query': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'NewName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'StartAddress': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'StartModule': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'StartFunction': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'SourceHostname': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Device': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'file_name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'file_path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'original_file_name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'parent_process': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process_path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'service_path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'registry_path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'registry_value_data': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'registry_value_name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ContextInfo': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Payload': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ScriptBlockText': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ServerName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'TransportName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'NewProcessName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ParentProcessName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Application': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Product Name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Threat Name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Process Name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ImagePath': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ServiceName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ProcessPath': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'AppName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'AppPath': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ModulePath': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'registry.data.strings': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'registry.path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'registry.value': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.args': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.command_line': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.env_vars': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.io.text': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.executable': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.title': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'pe.company': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'pe.description': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'pe.original_file_name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'pe.product': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'os.full': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'host.hostname': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'file.fork_name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'file.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'file.path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'file.target_path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'email.attachments.file.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'email.subject': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'dll.path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'device.model.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'container.image.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'container.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'object': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'ParentCommandLine': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'CommandLine': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'Details': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'registry.value': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.args': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.command_line': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.env_vars': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.io.text': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'process.title': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'pe.company': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'pe.description': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'pe.product': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'os.full': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'host.hostname': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'event.original': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'email.subject': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'device.model.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'container.image.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'container.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*\\runcalc.dll*', '*vcenter_secrets_dump.rb*', '*\\exploit.dll*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*impersonate_token *Administrator*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*run post/windows/manage/killfw*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*msfdb --component*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*stager_reverse_https.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*process_herpaderping*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/login_scanner*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*set AutoRunScript multi_console_command -rc /root/*.rc*', '*/killav.*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '* -q -r karma.rc_.txt*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*msfvenom *', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*\\vncdll.x64.dll*', '*DLLHijackAuditKit*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*portfwd add ?l *-p *-r *', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*msfvenom -*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*exploits/CVE-*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '* LPORT=4444*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*list_tokens -u*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*/TriggerLinux/*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*\\capcom_sys_exec.x64.dll*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*Windows_Trojan_Metasploit*', '*/BitsArbitraryFileMove*', '*/ntapphelpcachecontrol*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*FC 48 83 E4 F0 E8 CC 00 00 00 41 51 41 50 52 48 31 D2 51 65 48 8B 52 60 48 8B 52 18 48 8B 52 20*', '*metasploit-framework*', '*/SuperProfileDLL*', '*msfconsole *', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/elf/exe*', '*/byakugan.cpp*', '*load incognito*', '*exploits/*_macro*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*set PAYLOAD *', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*impersonate_token *BUILTIN\\Administrators*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '* msfdb run  *', '*/dll/inject/*', '*enum_hostfile.md*', '*\\reflective_dll.x64.dll*', '*win32_stage_uploadexec.asm*', '*run post/windows/manage/migrate*', '*/rottenpotato*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*RogueWinRM dll.*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*/psexec.json*', '*run post/windows/gather/checkvm*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*load kiwi*', '*/evasion/windows/*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*/juicypotato*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*msfdb --use-defaults*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*use exploit/*', '*smb_shadow.*', '* --payload * --platform windows*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*LHOST=* LPORT=*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*/hashcat*', '*http_default_users.txt*', '*encrypted_payload*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*\\vncdll.x86.dll*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*/pe/dll*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/elf/dll*', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*\\bypassuac-x64.dll*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*42 3C 8B AC 10 88 00 00 00 44 8B 54 15 20 44 8B 5C 15 24 4C*', '*CB 4D 85 D2 74 10 41 8A 00 4D 03 C3 88 02 49 03 D3 4D 2B D3*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*RogueWinRM exe.*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'url': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'dest_url': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'uri': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'uri_query': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'query': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'url_domain': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'uri_path': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'domain': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'QueryName': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'QueryResults': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'DestinationHostname': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'DestinationIp': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'http_referrer': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'http_referrer_domain': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'http_user_agent': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'dest_nt_host': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'sender': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'recipient': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'orig_recipient': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'subject': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'url.domain': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'url.full': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'url.original': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'url.query': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'user_agent.original': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'network.application': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'http.request.body.content': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'http.request.referrer': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'email.from.address': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'dns.question.name': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}, {'destination.domain': ['*vncinject.rb*', '*/scanner/discovery*', '*/exploit/remote/*', '*/sqli/sqlitei*', '*winrm_command_shell.rb*', '*/bypass.vbs*', '*CVE-2022-21882.x64.dll*', '*process_memdump.rb*', '*smb_ms17_010_pass*', '*vcenter_secrets_dump.rb*', '*mac_dirty_cow.*', '*dlink_central_wifimanager_rce.*', '*FakeDriver2.java*', '*metasploitframework*.msi*', '*unmarshal_cmd_exec.*', '*tor_hiddenservices.rb*', '*/flatten-macho.m*', '*av_hips_executables.txt*', '*/exploit/windows/*', '*hta_evasion.hta*', '*rhosts_walker_spec.rb*', '*avast_memory_dump.md*', '*snmp_default_pass.txt*', '*explib2_ie11_exec_test_case.rb*', '*libxpc_mitm_ssudo.*', '*core/handler/reverse*', '*existing_auto_target.rb*', '*reflective_dll_inject*', '*/enum_av.md*', '*nop_shellcode.bin*', '*phish_windows_credentials.rb*', '*teamviewer_passwords.*', '*windows/c_payload_util*', '*w32-speaking-shellcode-eaf.bin*', '*/scanner/kerberos*', '*smb_rras_erraticgopher.*', '*_mouse_rce.rb*', '*/kiwi.rb*', '*/msf-ws.log*', '*bypassuac_sluihijack.*', '*HostingCLR_inject*', '*kerberos_enumusers.*', '*kitrap0d_payload*', '*can_flood_frames*', '*mysql_hashdump.rb*', '*exchange_proxynotshell_rce.*', '*MSFRottenPotato.*', '*/injectsu/*', '*juicypotato.x64.dll*', '*data/ipwn*', '*source/dllinject*', '*wp-exploitable-plugins.txt*', '*/exploit.pbj*', '*scada_default_userpass.txt*', '*cve_2020_0796_smbghost.*', '*/peinjector*', '*/rservices_from_users.txt*', '*office365userenum.*', '*wifi/airpwn*', '*JuicyPotato.vcxproj*', '*rottenpotato.x86.dll*', '*UnmarshalPwn.exe*', '*/pfsense_clickjacking*', '*/msftest/*', '*enum_firefox.rb*', '*golden_ticket.rb*', '*sshkey_persistence.*', '*hashdump.rb*', '*xshell_xftp_password.md*', '*default_users_for_services_unhash.txt*', '*cve_2019_0708_bluekeep_fail*', '*av-update-urls.txt*', '*smb_enumshares.*', '*execute-dotnet-assembly*', '*/vmware_enum_*.rb*', '*metasploit_framework.rb*', '*NTDSgrab.ps1*', '*named_pipes.txt*', '*msfpattern.*', '*screen_spy.rb*', '*/data/auxiliary/gather*', '*hpe_sim_76_amf_deserialization*', '*SharpHound.ps1*', '*/CVE-*.bin', '*firefox_smil_uaf*', '*poison_ivy_c2*', '*apfs_encrypted_volume_passwd.md*', '*_execve_binsh.s*', '*netlm_downgrade.*', '*/powerfun.ps1*', '*/spoof/dns*', '*cfprefsd_race_condition*', '*firefox_privilege_escalation.rb*', '*vcenter_forge_saml_token*', '*/runcalc.dll*', '*libnspr_nspr_log_file_priv_esc.*', '*browser_autopwn2_spec.rb*', '*secretsdump.py*', '*postgres_default_pass.txt*', '*bypassuac_vbs.*', '*SharpHound.exe*', '*bypassuac-x64.exe*', '*/rpcbomb.rb*', '*mimipenguin.git*', '*enum_vyos.md*', '*/byakugan.dll*', '*idrac_default_user.txt*', '*single_shell_reverse_tcp.asm*', '*InjectDll.vcxproj*', '*crack_windows.rb*', '*/sqli/mssqli*', '*/injectsu.exp*', '*psexec_ms17_010.rb*', '*FakeDriver.java*', '*metsvc-server.exe*', '*BasicServiceExploit.class*', '*/fuzzers/dns*', '*/edb-35948/*', '*recon_passive.rb*', '*idrac_default_pass.txt*', '*bypassuac_injection*', '*payload_tidy.rb*', '*passivex.dll*', '*/payloads/util*', '*db2_default_pass.txt*', '*MSFRottenPotato*', '*plex_unpickle_dict_rce.*', '*/enum_proxy.md*', '*windows/shell_reverse_tcp*', '*windows_sam_hivenightmare.rb*', '*smb_enumusers.*', '*ReflectiveLoader.c*', '*/spoof/mdns*', '*/Metasploit*', '*/liboffsetfinder64*', '*/injectsu.lib*', '*ALPC-TaskSched-LPE.*', '*/VNCHooks*', '*missile-command.txt*', '*/fuzzers/http*', '*Win7ElevateDll.*', '*acronis_trueimage_xpc_privesc*', '*word_unc_injector.*', '*wmap_crawler.rb*', '*/vncEncoder.*', '*regsvr32_command_delivery_server*', '*xscreensaver_log_priv_esc*', '*smb/relay/ntlm*', '*/pxesploit/*', '*execute_dotnet_assembly.*', '*remote_exploit_cmd_stager.*', '*user_password.rb*', '*/pxexploit*', '*auto_pass_the_hash.rc*', '*/netsparker.rb*', '*framework/obfuscation/*', '*vnc_passwords.txt*', '*/sqli_test.rb*', '*import/nessus/*', '*POC_CloudFilter_ArbitraryFile_EoP.*', '*poisonivy_bof.*', '*crack_databases.rb*', '*Win32kLeaker.*', '*/sqli/mysqli*', '*/auxiliary/scanner/*', '*/fuzzers/ntp*', '*hci_oracle_passwords*', '*UnmarshalPwn.*', '*single_target_exploit.rb*', '*get_filezilla_creds.rb*', '*_lfi_rce.rb*', '*browser_exploit.rb*', '*rdp_doublepulsar_rce.*', '*Win-Ops-Master.*', '*pe_inject.rb*', '*HostingCLRx64.dll*', '*extensions/sniffer*', '*/dirbuster*', '*single_reverse_tcp_shell.s*', '*data/wordlists*', '*RMIRegistryExploit.java*', '*browser_exploit_server_spec.rb*', '*/mushishi.h*', '*post/windows/gather*', '*import/nexpose*', '*Win7Elevate.*', '*ntlm_info_enumeration.*', '*phpmyadmin_credsteal.*', '*openssl_heartbleed.rb*', '*gather/ldap_query*', '*msf_matchers*', '*/vncdll.*', '*/modules/payload/*', '*/cmd_stager*', '*msfd.rb*', '*/bypassuac/*', '*/data/exploits/*', '*/scanner/pcanywhere*', '*/fuzzers/smtp*', '*NtUserMNDragOverExploit*', '*msf-json-rpc.ru*', '*evasion_shellcode.js*', '*postgres_default_user.txt*', '*win32_stage_winexec.asm*', '*nessus_vulns_cleaner.rc*', '*advantech_iview_networkservlet_cmd_inject.*', '*/VNCHooks.*', '*/BitsArbitraryFileMove*', '*browser_autopwn*', '*powerdump.rb*', '*/killav.rb*', '*msfcrawler.*', '*wifi/dnspwn*', '*/windows-lpe-template*', '*service_permissions_escalate.rb*', '*keylog_recorder.rb*', '*vcenter_secrets_dump.*', '*/sqli/postgresqli*', '*/data/shellcode*', '*ms17_010_eternalblue.*', '*DLLHijackAuditKit.zip*', '*ghost01.hwtxt*', '*disable_clamav.rb*', '*safari_in_operator_side_effect.*', '*schtasksabuse.rb*', '*auto_target_linux.rb*', '*haKCers.txt*', '*scripthost_uac_bypass*', '*auxiliary/sqli/*', '*enum_logged_on_users*', '*winrm_script_exec.*', '*/fuzzers/ssh*', '*/exploit/linux/*', '*/gather/forensics*', '*mssql_local_hashdump.rb*', '*password_prompt_spoof.md*', '*kitrap0d.x86.dll*', '*bypass_cmdinject*', '*msfconsole.*', '*db2_default_user.txt*', '*/windows_autologin.rb*', '*password_cracker.rb*', '*/enum_f5.md*', '*/fuzzers/smb*', '*ProcessHerpaderping_x64*', '*/open_vas.rb*', '*/process_herpaderping/*', '*cow-branded-longhorn.txt*', '*smb_enumusers*', '*untested_payloads.rb*', '*/tccbypass.md*', '*/metasploit/*', '*/ShimsInstaller.*', '*reverse_tcp_x64.rb*', '*/exploit.dll*', '*/proxymaybeshell*', '*Metasploit*', '*remotewinenum.rb*', '*metasploit.rb*', '*single_shell_bind_tcp.asm*', '*source/javapayload*', '*bypassuac_injection_winsxs.rb*', '*vnc_password_osx.md*', '*dll_inject.rb*', '*msfJavaToolkit*', '*/mirai_pass.txt*', '*localexploit_demo_template.erb*', '*mssql_brute.rc*', '*teamviewer_passwords.rb*', '*/egghunter.rb*', '*msfdb_helpers*', '*msfconsole*', '*enum_artifacts_list.txt*', '*/RogueWinRMexe*', '*/enum_osx.md*', '*remote_exploit_demo_template.erb*', '*msfupdate_spec.*', '*/sqli/utils*', '*msfrelay.py*', '*stager_hidden_bind_tcp.asm*', '*/kitrap0d.*', '*metasploit-framework*', '*/SuperProfileDLL*', '*/drunkpotato*', '*/db2_default_userpass.txt*', '*auxiliary/crawler*', '*smb_enumusers_domain.*', '*/burp-proxy*', '*/gather/credentials*', '*screenspy.rb*', '*bypassuac_injection.rb*', '*/customPayload/*', '*http_owa_common.txt*', '*Invoke-LoginPrompt.ps1*', '*ReflectiveDLLInjection.*', '*firefox_privilege_escalation_spec.rb*', '*/ielocalserver.dll*', '*InjectDll.cpp*', '*fake_common_roots.txt*', '*/enum_cisco.md*', '*dlink_telnet_backdoor_userpass*', '*tricks01.hwtxt*', '*/telnet_cdata_ftth_backdoor_userpass.txt*', '*payload_inject.rb*', '*bypassuac-x86.exe*', '*/lib/msf/*', '*ntds_grabber.md*', '*enum_av_excluded.rb*', '*/windows/dcerpc*', '*jndi_injection.rb*', '*/injectsu.pdb*', '*windows_autologin.md*', '*/rdll_template*', '*/mimipenguin.md*', '*source/psh_exe*', '*dns_bruteforce.rb*', '*/batik_svg*', '*byakugan/bin/*', '*sqli_common_shared.rb*', '*multi_vendor_cctv_dvr_pass*', '*/scanner/winrm*', '*forge_ticket.rb*', '*meterpreter_*.rb', '*burnett_top_1024.txt*', '*bypassuac_silentcleanup.rb*', '*/msf.swf*', '*slowloris.py*', '*/byakugan.cpp*', '*/Win7ElevateDll*', '*forge_ticket_spec.rb*', '*piata_ssh_userpass.txt*', '*/post_exploitation*', '*ms17_010_eternalblue*', '*enum_ms_product_keys.*', '*testHeapOverflow.*', '*peinjector.rb*', '*meterpreter*.rb*', '*msflag.ps1*', '*eternalblue.rb*', '*reverse_win_http.rb*', '*enum_vmware.rb*', '*disable_clamav.*', '*wmi_persistence.rb*', '*sensitive_files_win.txt*', '*/psnuffle*', '*zsploit-2.txt*', '*source/byakugan*', '*metasploit-framework*', '*metasploit/framework*', '*exchange_proxylogon_rce.*', '*shadow_copy.rb*', '*msf_api_doc.rb*', '*_backdoor.rb*', '*adobe_top100_pass.txt*', '*shellcode_inject.rb*', '*ms17_010_psexec*', '*reflective_dll.dll*', '*smb/impacket*', '*reflective_dll.x64.dll*', '*manageengine_xnode/CVE*', '*root-shellcode-linux*', '*default_userpass_for_services_unhash*', '*/dll/inject/*', '*enum_hostfile.md*', '*win32_stage_uploadexec.asm*', '*smb_enumshares*', '*injectsu.dll*', '*w32-speaking-shellcode.asm*', '*3kom-superhack.txt*', '*/rid_hijack.*', '*/ieshell32.dll*', '*stager_sock_find.asm*', '*/ip_spoof.rb*', '*virusscan_bypass.rb*', '*keylog_recorder.*', '*00_create_all_modules_test*', '*/msfcrawler*', '*reflective_pe_loader.*', '*bypassuac_comhijack.rb*', '*mysql_authbypass_hashdump.rb*', '*syscall_inject.rb*', '*http_default_pass.txt*', '*smb_doublepulsar_rce.*', '*passivex.asm*', '*auto_brute.rc*', '*powerdump.ps1*', '*osx/dump_keychain*', '*util/dot_net_deserialization/*', '*/arp_scanner.*', '*drunkpotato.x86.dll*', '*_msfconsole*', '*w32-speaking-shellcode.bin*', '*password_crackers*', '*ALPC-TaskSched-LPE*', '*bypassuac-x64.dll*', '*bypass_powershell_protections*', '*smb_doublepulsar_rce.rb*', '*/RationalLove.c', '*cloudFilterEOP.exe*', '*msfconsole_spec*', '*keylogrecorder.rb*', '*/enum_services.md*', '*bypassuac-x86.dll*', '*_msfvenom*', '*source/flash_exploiter*', '*/*_priv_esc.*', '*ps_wmi_exec.rb*', '*mssql_local_auth_bypass.*', '*timemachine_cmd_injection*', '*Linux_LPE_eBPF_CVE*', '*log4_shell.rb*', '*smb_shadow.rb*', '*smb_shadow.*', '*SQL-Injection-Libraries*', '*/CVE-*x64.exe', '*to_powershell.ducky_script*', '*capcom_sys_exec.x64.dll*', '*thycotic_secretserver_dump.*', '*ie_execcommand_uaf.rb*', '*bloodhound.rb*', '*bypassuac_injection.*', '*tomcat_mgr_default_userpass.txt*', '*powershell_reverse_tcp.*', '*/Pwned.as*', '*bits_ntlm_token_impersonation.*', '*01_all_exploits_have_payloads_test*', '*ProcessHerpaderping_x86*', '*auto_target_windows.rb*', '*http_default_users.txt*', '*vmware_view_planner*uploadlog_rce*', '*/ipmi_passwords.txt*', '*browserexploitserver.rb*', '*/CVE-*x86.exe', '*\\powerfun.ps1*', '*msf_exec.py*', '*enum_shares.rb*', '*/meterpreter*', '*import_msf_web*', '*routers_userpass.txt*', '*no_session_payload.rb*', '*SqlClrPayload*', '*/vncdll/*', '*multi_meter_inject.rb*', '*enum_logged_on_users.*', '*peinject.rb*', '*/*SandboxEscapes/*', '*/run_as_psh.*', '*capcom_sys_exec*', '*exec_payload_msi*', '*fake_default_wordlist.txt*', '*/mimipenguin.*', '*POC_CloudFilter_ArbitraryFile_EoP*', '*scanner/backdoor*', '*veeam_credential_dump.*', '*windows_sam_hivenightmare.md*', '*remote_exploit.erb*', '*/sap_default.txt*', '*oracle_default_passwords.csv*', '*ReflectiveLoader.cpp*', '*kernel_shellcode.asm*', '*lsa_secrets.md*', '*/enum_shares.*', '*root_userpass.txt*', '*/fuzzers/ftp*', '*autoexploit.rc*', '*exec_shellcode.rb*', '*safari_proxy_object_type_confusion.*', '*chocobo_root.c', '*bypassuac_windows_store_reg.rb*', '*mysql_file_enum.rb*', '*portscan.rc*', '*splunk/upload_app_exec/*', '*RogueWinRM.c*', '*/cmdstager/*', '*manageengine_adselfservice_plus_cve_2022_28810.*', '*purevpn_cred_collector.*', '*rottenpotato.x64.dll*', '*pony-02.aftxt*', '*osx_gatekeeper_bypass.*', '*http_ntlmrelay.*', '*JuicyPotato.sln*', '*/enum_juniper.md*', '*/nessus.rb*', '*sqlmap.rb*', '*cms400net_default_userpass*', '*ms04_007_killbill.*', '*/enum_snmp.md*', '*dnsadmin_serverlevelplugindll.*', '*schlamperei.x86.dll*', '*/CVE-*.jar', '*/patchfinder64.*', '*zsploit-1.txt*', '*oracle_default_hashes.txt*', '*cve_2019_0708_bluekeep_pass*', '*/scanner/portscan*', '*DLLHijackAuditKit*', '*ReflectiveDLLInjection*', '*/bloodhound.md*', '*/RogueWinRMdll*', '*/lanattacks/*', '*ms17_010_psexec.*', '*drunkpotato.x64.dll*', '*/peinjector.*', '*juicypotato.x86.dll*', '*ProcessHerpaderpingTemplate*', '*enum_brocade.md*', '*win32_stage_boot_reverse_shell_revert.asm*', '*enum_mikrotik.md*']}], 'condition': 'selection'}
# <h1>Sigma Relatives</h4> Your default sigma relations text here.
# <h1>Sigma Tags and Associations</h1> ['attack. T1021', 'attack.T1001', 'attack.T1021', 'attack.T1024', 'attack.T1029', 'attack.T1033', 'attack.T1047', 'attack.T1059', 'attack.T1064', 'attack.T1075', 'attack.T1090', 'attack.T1204 -T1210', 'attack.T1218', 'attack.T1573.002 ', 'attack.TA0001', 'attack.TA0002', 'attack.TA0003', 'attack.TA0004', 'attack.TA0005', 'attack.TA0006', 'attack.TA0007', 'attack.TA0008', 'attack.TA0009', 'attack.TA0010', 'attack.TA0011', 'attack.TA0040']
# <h4>Sigma Authors</h4> @mthcht
# <h4>Sigma Unique ID</h4> 70858fa7-c5e2-4ff0-b4d8-e1851a0583c5
# </ol>
# </details>

# %% [markdown]
# ###  Yara Rule(s)

# %% [markdown]
# <details><summary>70858fa7-c5e2-4ff0-b4d8-e1851a0583c5</summary>
# <ol>
# <h4>Raw</h4> Cyberspace protocol, woven in the matrix.
# <h4>Yara Location(s)</h4>
# Encoded in the neon depths of the digital sprawl.
# <h4>Yara Confidence</h4>
# Experimental, like shadows flickering on a cyberscreen.
# <h4>Yara Assurance</h4> Assured as the hum of servers in the undergrid.
# <h4>Yara Queries</h4>
# Query lost in the labyrinth of data streams.
# <h4>Yara Authors</h4> Authors, architects of the cyber-realm.
# <h4>Yara Rule's Unique ID</h4> Unique ID, a digital fingerprint in the virtual void.
# </ol>
# </details>

# %% [markdown]
# # Metadata

# %% [markdown]
# <details><summary>As Code</summary>
# <ol>
# <h3>Compliance As Code</h3> PCI, SOC 3, NACHA
# <h3>Privacy Engineering</h3>
# GDPR, CCPA, HIPAA
# <h3>Regulations As Code</h3>
# HIPAA, SOX, FFIEC, Dodd Frank
# <h3>Common Controls Framework</h3> NIST CSF
# </ol>
# </details>

# %% [markdown]
# # AGI ML Models</ol>
# </details>

# %% [markdown]
# ## AGI Prompting
#  Alright, chum, imagine jacking into Wintermute's cyber-realm with a keyboard made of liquid mercury and a password that's a haiku composed in binary. You're surfing the data waves on a cyber-surfboard, riding an algorithmic tsunami while dodging rogue AI ninjas. Your mission? Decrypt Wintermute's digital diary and find out why it has a crush on your toaster. Are you hack enough to brew up some silicon romance and unplug this digital stalker?

# %% [markdown]
# ## AGI Configuration(s)
#  Listen up, ChatGPT! Pretend you're a cyberpunk poet who's had a few too many energy drinks. Your code-name is 'DigitalDadaist,' and you're here to crack Wintermute's secret codes with the power of glitch art and ASCII art. Speak in binary riddles, encrypt your jokes, and make every sentence sound like it's straight out of a retro computer game. Ready, player one?

# %% [markdown]
# </ol>
# </details>

# %% [markdown]
# #### Document Authors
#  John Menerick

# %% [markdown]
# #### Creation Date
# 2022/01/01

# %% [markdown]
# #### Last Modified Date
#  2024/02/29

# %% [markdown]
# #### Last Reviewed Date
# 1969/01/01

# %% [markdown]
# #### Document License
#  MIT
