# %% [markdown]
# # UNCLASSIFIED / NON CLASSIFIÉ//TLP:WHITE# U/OO/{random.randint(4365, 862901)}-02 | QQ-09-1998
#  Please note that the original, detailed content has been removed or adjusted for public consumption. Most data has been redacted and replaced with generic, non-actionable insights. This modification ensures compliance with privacy considerations, non-disclosure agreements, and intellectual property rights that govern the dissemination of sensitive information. The priority is to respect these boundaries while still offering valuable, thought-provoking perspectives.

# %% [markdown]
# ![Build Status](https://img.shields.io/badge/Build-Passing-brightgreen?style=flat-square&logo=cyberpunk)         ![Documentation](https://img.shields.io/badge/Documentation-Complete-blue?style=flat-square&logo=cyberpunk)        ![Response Efficiency](https://img.shields.io/badge/Response%20Efficiency-98%25-green?style=flat-square&logo=cyberpunk)        ![Last Updated](https://img.shields.io/badge/Last%20Updated-Oct%202023-purple?style=flat-square&logo=cyberpunk)        ![Incidents Resolved](https://img.shields.io/badge/Incidents%20Resolved-150-red?style=flat-square&logo=cyberpunk)        ![Community Engagement](https://img.shields.io/badge/Community-Active-orange?style=flat-square&logo=cyberpunk)        ![Code Integration](https://img.shields.io/badge/Code%20Integration-High-teal?style=flat-square&logo=cyberpunk)        ![AI Analysis](https://img.shields.io/badge/AI%20Analysis-Advanced-blueviolet?style=flat-square&logo=cyberpunk)        ![Threat Detection](https://img.shields.io/badge/Threat%20Detection-Optimal-red?style=flat-square&logo=cyberpunk)        ![Cybersecurity Hardening](https://img.shields.io/badge/Security-Hardened-silver?style=flat-square&logo=cyberpunk)        ![Network Uptime](https://img.shields.io/badge/Uptime-99.9%25-brightgreen?style=flat-square&logo=cyberpunk)        ![Data Privacy](https://img.shields.io/badge/Privacy-Compliant-green?style=flat-square&logo=cyberpunk)        ![Wintermute Efficiency](https://img.shields.io/badge/Wintermute%20Efficiency-100%25-black?style=flat-square&logo=cyberpunk)        ![Case's Code Agility](https://img.shields.io/badge/Case's%20Code%20Agility-Excellent-blue?style=flat-square&logo=cyberpunk)        ![Matrix Connectivity](https://img.shields.io/badge/Matrix%20Connectivity-Strong-green?style=flat-square&logo=cyberpunk)        ![Molly's Security](https://img.shields.io/badge/Molly's%20Security%20Protocols-Impeccable-red?style=flat-square&logo=cyberpunk)        ![Chiba City Innovation](https://img.shields.io/badge/Chiba%20City%20Innovation-High-yellow?style=flat-square&logo=cyberpunk)        ![Zion Cluster Collaboration](https://img.shields.io/badge/Zion%20Cluster%20Collaboration-Effective-lightblue?style=flat-square&logo=cyberpunk)

# %% [markdown]
# # Title
# Simple keyword detection rule for exegol

# %% [markdown]
# # Description
# Detects interesting keywords based on exegol tool

# %% [markdown]
# # Goal
# Ensure the integrity, confidentiality, and availability by rapidly identifying, investigating, and mitigating cyber threats and anomalies.

# %% [markdown]
# # Categorization

# %% [markdown]
# ### ATT&CK
# ['attack.?', 'attack.T1078', 'attack.T1095', 'attack.T1140', 'attack.T1218', 'attack.T1543', 'attack.T1547', 'attack.T1559', 'attack.T1571', 'attack.TA0002', 'attack.TA0003', 'attack.TA0004', 'attack.TA0011', 'attack.TA0043']

# %% [markdown]
# - Distributed Denial of Service (DDoS) Attacks, Quantum Computing Exploits, Advanced Firewall Breach Attempts, Encryption Key Theft or Exposure, AI-Powered Social Engineering Attacks, Algorithmic Manipulation and Exploits, Sophisticated Malware Infiltrations, Advanced Data Obfuscation and Evasion Tactics, System and Network Configuration Vulnerabilities.

# %% [markdown]
# - Data Exfiltration, Intrusion Detection Evasion, Denial of Service (DoS) Attacks, Credential Theft.

# %% [markdown]
# - DNS Tunneling, IP Spoofing, Distributed DoS (DDoS) Attacks, Keylogging.

# %% [markdown]
# ### D3F3ND

# %% [markdown]
# <ul>
#   <li><strong>Network Segmentation and Access Control (D3F3ND-K001):</strong> Establish secure network zones by segmenting the infrastructure, enhancing protection for critical assets. Implement stringent access controls to prevent unauthorized access and mitigate potential threats.</li>
#
#   <li><strong>Advanced Endpoint Protection Deployment (D3F3ND-K002):</strong> Deploy cutting-edge endpoint security solutions that utilize machine learning and behavioral analysis to detect and neutralize threats proactively.</li>
#
#   <li><strong>Enhanced Identity Verification (D3F3ND-K003):</strong> Strengthen security measures with multi-factor authentication combining biometric data and advanced encryption to prevent identity theft and unauthorized access.</li>
#
#   <li><strong>Anomaly Detection (D3F3ND-K004):</strong> Use anomaly detection tools to monitor for unusual traffic patterns, user activities, and system behaviors to identify potential security breaches early.</li>
#
#   <li><strong>Data Encryption (D3F3ND-K005):</strong> Apply robust encryption techniques to protect data at rest and in transit, ensuring confidentiality and integrity across communication channels.</li>
#
#   <li><strong>System Hardening and Vulnerability Management (D3F3ND-K006):</strong> Conduct regular security assessments and apply patches promptly to address vulnerabilities and strengthen system defenses.</li>
#
#   <li><strong>Crisis Management and Recovery Protocols (D3F3ND-K007):</strong> Develop and maintain comprehensive crisis management plans including incident response and disaster recovery procedures to quickly recover from security incidents.</li>
#
#   <li><strong>Threat Intelligence Integration (D3F3ND-K008):</strong> Leverage threat intelligence platforms to gather and analyze data on emerging threats, enabling proactive defense and strategic decision-making.</li>
#
#   <li><strong>Cybersecurity Awareness Training (D3F3ND-K009):</strong> Empower employees with ongoing cybersecurity education to recognize and avoid potential cyber threats such as phishing attacks.</li>
#
#   <li><strong>Supply Chain Security (D3F3ND-K010):</strong> Secure the supply chain through continuous assessments and audits of partners and vendors to ensure compliance with security standards and reduce vulnerabilities.</li>
# </ul>

# %% [markdown]
# ### CAPEC

# %% [markdown]
# Equip cybersecurity teams with the knowledge and tools to identify, counter, and mitigate a wide range of digital attack tactics, techniques, and procedures (TTPs). This effort requires understanding the attacker's mindset, mastering the execution of digital attacks, and developing strategies to confront evolving cyber threats.</br><h4>Core Attack Patterns</h4><ul><strong>Resource Manipulation and Denial (CAPEC-XYZ1):</strong> Involves attacks that compromise the availability, integrity, or confidentiality of resources. This includes denial of service attacks as well as more covert operations like resource hijacking or system manipulation.</ul><ul><strong>Credential Access and Privilege Escalation (CAPEC-XYZ2):</strong> Focuses on exploiting flaws in authentication, authorization, and session management to gain unauthorized access or elevated privileges within systems.</ul><ul><strong>Data Exfiltration and Infiltration (CAPEC-XYZ3):</strong> Encompasses methods used by attackers to stealthily extract sensitive data or introduce malware, ransomware, and advanced persistent threats (APTs) into target systems.</ul><ul><strong>Social Engineering and Phishing (CAPEC-XYZ4):</strong> Involves manipulating individuals into divulging confidential information, compromising security, or unknowingly participating in attacks.</ul><ul><strong>Evasive Maneuvers (CAPEC-XYZ5):</strong> Includes techniques that allow attackers to remain undetected within networks, maintain persistence, and erase traces of their activities, such as using obfuscation, rootkits, and covert communication channels.</ul><h4>CAPEC Suggested Mitigation Strategies</h4><ul><strong>Continuous Monitoring and Anomaly Detection:</strong> Implement comprehensive monitoring systems that use machine learning algorithms to detect abnormal behavior and potential threats. Regularly review logs and alerts to identify patterns indicative of attacks.</ul><ul><strong>Access Control and Least Privilege:</strong> Limit user privileges to the minimum necessary for their roles. Use strong authentication mechanisms and enforce strict access controls to prevent unauthorized access.</ul><ul><strong>Secure Software Development Practices:</strong> Train developers to write secure code, conduct regular security assessments, and follow best practices for secure coding. Use automated tools to identify vulnerabilities during development.</ul><ul><strong>Incident Response Planning and Testing:</strong> Develop and regularly update an incident response plan. Conduct tabletop exercises and simulations to test the effectiveness of the plan and ensure all stakeholders understand their roles during a security incident.</ul>

# %% [markdown]
# ## Strategy Abstract
# In the complex environment of cybersecurity, a strategic approach is developed, characterized by the use of sophisticated tactics and algorithms. This strategy involves navigating through encrypted communications and deceptive tactics, aiming to gain an advantage in the dynamic flow of information. While success is often elusive and challenging to sustain, it remains a critical goal in the ongoing effort to secure digital assets.

# %% [markdown]
# # Technical Context
# In the challenging cybersecurity landscape, the confrontation with Wintermute involves navigating encrypted communications, interacting with AI systems, and addressing quantum computing challenges. This setting represents a complex and nuanced environment where strategic decisions are made.

# %% [markdown]
# ## Blind Spots & Assumptions
#
# <ul>
#   <li><strong>Overlooked Vulnerabilities:</strong> We often miss subtle system signals or vulnerabilities, assuming our defenses are robust. Constant vigilance and seeking what we haven't seen are crucial.</li>
#
#   <li><strong>Advanced Adversary Tactics:</strong> Cyber threats evolve rapidly; yesterday's defense may not guard against tomorrow's attack. Stay adaptive and expect the unexpected.</li>
#
#   <li><strong>Internal System Flaws:</strong> Trust in our systems and allies must be balanced with scrutiny. Regularly audit internal and third-party tools for hidden weaknesses.</li>
#
#   <li><strong>Network Interconnectivity Risks:</strong> No system is an island. The interconnected nature of our digital environment can inadvertently open pathways for attackers.</li>
#
#   <li><strong>Historical Bias:</strong> Preparing for future threats based solely on past incidents may leave us blind to novel attacks. Foster a forward-thinking, proactive defense posture.</li>
# </ul>

# %% [markdown]
# # Validating this Playbook
# <details><summary>Triage, triage, triage</summary>
# <ol>
# <h2>False Positives:</h2> ['unknown']
# <h3>False Negatives:</h3> Undetected threats concealed within the system's code
# <h3>True Negatives:</h3> Successfully identified and verified benign elements
# <h3>True Positives:</h3> Accurately detected and confirmed threats
# </ol>
# </details>

# %% [markdown]
# <details><summary>Assurance Verification Techniques</summary>
# <ol>
# <h2>False Positives:</h2> In the noisy environment of data analysis, false positives appear as misleading alerts that mimic real threats. Validating these alerts involves distinguishing irrelevant data from true threats, a process crucial for maintaining operational efficiency and avoiding resource wastage. Each false positive represents a challenge to identify and reduce noise.
# <h3>False Negatives:</h3> Within the extensive network, false negatives represent undetected threats that evade algorithmic detection. Their validation involves analyzing complex data to uncover hidden breaches, where the lack of alerts may mask serious security risks. Each undetected threat requires continuous vigilance and refined detection strategies.
# <h3>True Negatives:</h3> True negatives are correctly identified non-threats within cybersecurity defenses, serving as indicators of system efficacy. Validating these instances confirms the absence of threats, reinforcing the effectiveness of the security measures in place. This validation underscores the reliability of the defensive systems, where non-issues are accurately identified and dismissed.
# <h3>True Positives:</h3> True positives are accurate detections of real threats within the digital environment. Validating these alerts confirms the presence of actual security threats, highlighting the successful operation of detection systems. Each true positive affirms the effectiveness of the security protocols, contributing to ongoing improvements in threat response capabilities.
# </ol>
# </details>

# %% [markdown]
# # Datasets
#  Detailing the timeless struggle                                                          for the defenders know that battle against Wintermute is not just about data.                                                          Document any datasets that may be useful for understanding the book.

# %% [markdown]
# ## Playbook test data location(s)
# protocol://black_market.cyber/decrypt?currency=bitcoffin&password=cyberpunks_unite&target=neurohacked_mainframe&access_code=cyber_ghost_in_the_machine

# %% [markdown]
# ## Priority
# Priority based on complexity and urgency of data analysis needs

# %% [markdown]
# ## Logsources

# %% [markdown]
# <details><summary>{'category': ['endpoint', 'network'], 'product': '', 'service': ''}</summary>
# <ol>
# <h3>Product</h3> {''}
# <h3>Service</h3> {''}
# </ol>
# </details>

# %% [markdown]
# # Response and Mitigation
# This statement details the enduring challenges faced by cybersecurity defenders, emphasizing that the conflict with Wintermute extends beyond simple data protection to encompass broader aspects of strategic cybersecurity defense.

# %% [markdown]
# ## Analyst Notes
#  <h5>Significant Security Breach Analysis:</h5><ul><li><strong>Advanced Intrusion Tactics:</strong> The intruder displayed sophisticated methods in circumventing digital security measures, reminiscent of complex evasion techniques in cybersecurity. A comprehensive analysis of the techniques used is required.</li><li><strong>Neural Network Manipulation:</strong> The intruder demonstrated a deep understanding of the neural networks, suggesting an advanced level of AI interaction. Investigate the potential implications of this interaction on system security and integrity.</li><li><strong>Complex Digital Constructs:</strong> The breach uncovered intricate digital constructs within the system, indicating the use of advanced artificial intelligence in creating deceptive environments. Further investigation into these constructs is necessary.</li><li><strong>Encoded Communications:</strong> Cryptic messages were found embedded in the intruder's code, requiring decryption and analysis to understand their content and purpose.</li><li><strong>Algorithmic Complexity:</strong> The intrusion involved complex algorithms that may have interacted with core system functions. Assess the impact of these algorithms on system operations and security.</li><li><strong>Expertise vs. Sentience:</strong> The intruder's ability to navigate complex neural networks raises questions about the nature of the intelligence involved—whether it is merely advanced programming or something approaching sentience.</li><li><strong>Innovative Security Measures:</strong> Inspired by the breach, consider developing new security protocols that can better identify and respond to sophisticated AI-driven attacks.</li><li><strong>Philosophical and Ethical Implications:</strong> The breach raises important questions about the ethical and philosophical implications of AI-driven intrusions. Explore the boundaries between artificial expertise and true sentience, and consider the impact on our understanding of intelligence and security.</li></ul>

# %% [markdown]
# # Additional Resources
# <ul><li>https://github.com/ThePorgs/Exegol</li></ul>

# %% [markdown]
# ###  Sigma Rule(s)

# %% [markdown]
# <details><summary>d57d521f-f6c9-4d65-a0e8-d0990b32623d</summary>
# <ol>
# <h1>Raw</h1> {'title': 'Simple keyword detection rule for exegol', 'id': 'd57d521f-f6c9-4d65-a0e8-d0990b32623d', 'status': 'experimental', 'description': 'Detects interesting keywords based on exegol tool', 'references': ['https://github.com/ThePorgs/Exegol'], 'author': '@mthcht', 'date': '2022/01/01', 'modified': '2024/02/29', 'tags': ['attack.?', 'attack.T1078', 'attack.T1095', 'attack.T1140', 'attack.T1218', 'attack.T1543', 'attack.T1547', 'attack.T1559', 'attack.T1571', 'attack.TA0002', 'attack.TA0003', 'attack.TA0004', 'attack.TA0011', 'attack.TA0043'], 'logsource': {'category': ['endpoint', 'network']}, 'detection': {'selection': [{'Image': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'OriginalFileName': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'CurrentDirectory': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ParentImage': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ParentCommandLine': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'TargetFilename': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Signature': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'signature': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ImageLoaded': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Company': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Description': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'description': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'CommandLine': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'SourceImage': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'TargetImage': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'CallTrace': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'TargetObject': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Details': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'PipeName': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Consumer': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Destination': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Query': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'NewName': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'StartAddress': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'StartModule': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'StartFunction': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'SourceHostname': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Device': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'file_name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'file_path': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'original_file_name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'parent_process': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process_path': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'service_path': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'registry_path': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'registry_value_data': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'registry_value_name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ContextInfo': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Payload': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ScriptBlockText': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ServerName': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'TransportName': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'NewProcessName': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ParentProcessName': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Application': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Product Name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Threat Name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Process Name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Path': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ImagePath': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ServiceName': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ProcessPath': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'AppName': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'AppPath': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ModulePath': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'registry.data.strings': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'registry.path': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'registry.value': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.args': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.command_line': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.env_vars': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.io.text': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.executable': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.title': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'pe.company': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'pe.description': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'pe.original_file_name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'pe.product': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'os.full': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'host.hostname': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'file.fork_name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'file.name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'file.path': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'file.target_path': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'email.attachments.file.name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'email.subject': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'dll.path': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'device.model.name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'container.image.name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'container.name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'object': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ParentCommandLine': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'CommandLine': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Details': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'registry.value': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.args': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.command_line': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.env_vars': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.io.text': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.title': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'pe.company': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'pe.description': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'pe.product': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'os.full': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'host.hostname': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'event.original': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'email.subject': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'device.model.name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'container.image.name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'container.name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Hashes': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'file_hash': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'hash.md5': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'hash.sha1': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'hash.sha256': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'hash.sha384': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'hash.sha512': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'hash.ssdeep': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'service_hash': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'description': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'url': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'dest_url': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'uri': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'uri_query': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'query': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'url_domain': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'uri_path': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'domain': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'QueryName': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'QueryResults': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'DestinationHostname': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'DestinationIp': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'http_referrer': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'http_referrer_domain': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'http_user_agent': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'dest_nt_host': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'sender': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'recipient': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'orig_recipient': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'subject': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'url.domain': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'url.full': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'url.original': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'url.query': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'user_agent.original': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'network.application': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'http.request.body.content': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'http.request.referrer': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'email.from.address': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'dns.question.name': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'destination.domain': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}], 'condition': 'selection'}, 'fields': ['Image', 'OriginalFileName', 'CurrentDirectory', 'ParentImage', 'ParentCommandLine', 'TargetFilename', 'Signature', 'signature', 'ImageLoaded', 'Company', 'Description', 'description', 'CommandLine', 'SourceImage', 'TargetImage', 'CallTrace', 'TargetObject', 'Details', 'PipeName', 'Consumer', 'Destination', 'Name', 'Query', 'NewName', 'StartAddress', 'StartModule', 'StartFunction', 'SourceHostname', 'Device', 'file_name', 'file_path', 'process', 'original_file_name', 'parent_process', 'process_path', 'service_path', 'registry_path', 'registry_value_data', 'registry_value_name', 'ContextInfo', 'Payload', 'ScriptBlockText', 'ServerName', 'TransportName', 'NewProcessName', 'ParentProcessName', 'Application', 'Product Name', 'Threat Name', 'Process Name', 'Path', 'ImagePath', 'ServiceName', 'ProcessPath', 'AppName', 'AppPath', 'ModulePath', 'registry.data.strings', 'registry.path', 'registry.value', 'process.args', 'process.command_line', 'process.env_vars', 'process.io.text', 'process.executable', 'process.name', 'process.title', 'pe.company', 'pe.description', 'pe.original_file_name', 'pe.product', 'os.full', 'host.hostname', 'file.fork_name', 'file.name', 'file.path', 'file.target_path', 'email.attachments.file.name', 'email.subject', 'dll.path', 'device.model.name', 'container.image.name', 'container.name', 'object', 'ParentCommandLine', 'CommandLine', 'Details', 'registry.value', 'process.args', 'process.command_line', 'process.env_vars', 'process.io.text', 'process.title', 'pe.company', 'pe.description', 'pe.product', 'os.full', 'host.hostname', 'event.original', 'email.subject', 'device.model.name', 'container.image.name', 'container.name', 'Hashes', 'file_hash', 'hash.md5', 'hash.sha1', 'hash.sha256', 'hash.sha384', 'hash.sha512', 'hash.ssdeep', 'service_hash', 'description', 'url', 'dest_url', 'uri', 'uri_query', 'query', 'url_domain', 'uri_path', 'domain', 'QueryName', 'QueryResults', 'DestinationHostname', 'DestinationIp', 'http_referrer', 'http_referrer_domain', 'http_user_agent', 'dest_nt_host', 'sender', 'recipient', 'orig_recipient', 'subject', 'url.domain', 'url.full', 'url.original', 'url.query', 'user_agent.original', 'network.application', 'http.request.body.content', 'http.request.referrer', 'email.from.address', 'dns.question.name', 'destination.domain'], 'falsepositives': ['unknown'], 'level': 'medium'}
# <h4>Sigma Location(s)</h4>
# uri://wintermute/tmp/0day.yml
# <h4>Sigma Confidence</h4>
# experimental
# <h4>Sigma Assurance</h4> medium
# <h4>Sigma Queries</h4>
# {'selection': [{'Image': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'OriginalFileName': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'CurrentDirectory': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ParentImage': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ParentCommandLine': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'TargetFilename': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Signature': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'signature': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ImageLoaded': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Company': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Description': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'description': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'CommandLine': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'SourceImage': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'TargetImage': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'CallTrace': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'TargetObject': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Details': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'PipeName': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Consumer': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Destination': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Query': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'NewName': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'StartAddress': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'StartModule': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'StartFunction': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'SourceHostname': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Device': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'file_name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'file_path': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'original_file_name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'parent_process': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process_path': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'service_path': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'registry_path': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'registry_value_data': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'registry_value_name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ContextInfo': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Payload': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ScriptBlockText': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ServerName': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'TransportName': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'NewProcessName': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ParentProcessName': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Application': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Product Name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Threat Name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Process Name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Path': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ImagePath': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ServiceName': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ProcessPath': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'AppName': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'AppPath': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ModulePath': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'registry.data.strings': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'registry.path': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'registry.value': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.args': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.command_line': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.env_vars': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.io.text': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.executable': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.title': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'pe.company': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'pe.description': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'pe.original_file_name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'pe.product': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'os.full': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'host.hostname': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'file.fork_name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'file.name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'file.path': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'file.target_path': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'email.attachments.file.name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'email.subject': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'dll.path': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'device.model.name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'container.image.name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'container.name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'object': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'ParentCommandLine': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'CommandLine': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Details': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'registry.value': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.args': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.command_line': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.env_vars': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.io.text': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'process.title': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'pe.company': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'pe.description': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'pe.product': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'os.full': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'host.hostname': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'event.original': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'email.subject': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'device.model.name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'container.image.name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'container.name': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'Hashes': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'file_hash': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'hash.md5': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'hash.sha1': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'hash.sha256': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'hash.sha384': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'hash.sha512': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'hash.ssdeep': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'service_hash': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'description': ['*python3 rsf.py*', '*webshell-exegol.php*', '*install_manspider*', '*install_pkinittools*', '*tarunkant/Gopherus*', "*net rpc group members 'Domain admins' -U *", '* ntlmv1.py*', '*bruteforce-luks -*', '*ssrfmap -r *.txt -p id -m readfiles*portscan*', '*winPEAS.bat*', '*ExegolController.py*', '*responder-smb-on*', '*jdwp-shellifier.py -t * -p * --cmd *', '* --isroca --publickey *', '*install_lsassy*', '*install_gpp-decrypt*', '*ip route add * dev ligolo*', '*airodump-ng *', '*/root/.mozilla/firefox/*.Exegol*', '*bruteforce-luks -t 4 -l 5 -m 5 /dev/sdb1*', '*tailscaled --tun=userspace-networking --socks5-server=*', '*ftp-server -u * -P * -p 2121*', '* --script=realvnc-auth-bypass *', '*getST.py -k -no-pass -spn*', '*snmpwalk -c public -v 2c *', '*getTGT.py -dc-ip *', '*/var/log/exegol/*.log*', '*wafw00f https://*', '* deepce.sh *--install*', '* -s * --method 1 --function shell_exec --parameters cmd:id*', '* -f *.dmp windows.registry.hivelist*', '*prowler gcp --credentials-file path*', '*smbexec.py -hashes :*', '*proxychains secretsdump*', '* install evil-winrm*', '*/opt/.exegol_aliases*', '*subfinder -d *', '* --interface * --analyze --disable-ess*', '*dacledit.py -action write -rights DCSync -principal * -target-dn *', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*install_pylaps*', '* --convert_idrsa_pub --publickey $HOME/.ssh/id_rsa.pub*', '* --wpad --lm --ProxyAuth --disable-ess**', '* --host * --port * --executable *.exe --command *cmd.exe*', '*/targetedKerberoast.py*', '*kerbrute passwordspray *', '*photon.py -u * -l 3 -t 100 --wayback*', '*danielmiessler/SecLists*', '*Exegol-images-main*', '*byt3bl33d3r/pth-toolkit*', "*reg.py *@* save -keyName 'HKLM\\SAM*", '*bloodhound-quickwin -u * -p *', '*danielmiessler/SecLists.git*', '*install_ldapsearch-ad*', '*nbtscan -r */24*', '*jackit --reset --debug*', '*Hackndo/sprayhound*', '*linpeas_darwin_arm64*', '*pyrit -r *.pcap -b * -i *.txt attack_passthrough*', '*dirb *http* /usr/share/seclists/Discovery/Web-Content/big.txt*', '*bettercap -iface eth0*', '*tls-scanner -connect *:*', '* --shell tcsh exegol*', '*install_certsync*', '*install_rusthound*', '*ShawnDEvans/smbmap*', '* -d * -u * -p * --listener * --target *$DC_HOST*', '*responder-http-on*', '*winPEASx86_ofs.exe*', '*-smb2support --remove-mic --shadow-credentials --shadow-target *', '*/Responder/Responder.conf*', '*hcxpcapngtool --all -o *.hashcat*', '*pass-station search tomcat*', '* -f *.dmp windows.dlllist --pid *', '*smbpasswd.py -newpass *', '*install_windapsearch-go*', '*\\Exegol-*.zip*', '* lsass_creds.txt*', '*install_responder*', '*spiderfoot -l 127.0.0.1:*', '*hackrf_sweep -f *', '*pwndb --target @* --output *', '*fcrackzip -u -v -D -p *.zip*', '* /.exegol/*', '*patator ftp_login host=* user=FILE0 0=*.txt *', '* --set-as-owned smart -bp * kerberos * --kdc-ip *', '*install_smtp-user-enum*', '*register-python-argcomplete --no-defaults exegol*', '*bloodhound-import -du neo4j -dp *.json*', '*evil-winrm -*', '*dirkjanm/ldapdomaindump*', '*install_pykek*', '*cypheroth -u neo4j -p *', '* --hash-type * --attack-mode *', '*pywhisker.py -*', '*wmiexec.py -*', '*kraken.py --connect --mode * --profile * --compiler *', '*pygpoabuse * -hashes lm:* -gpo-id *', '*install_ruler*', '*nmap -Pn -v -sS -F*', '*smbexec.py -share*', '*roastinthemiddle -i * -t * -u *.txt -g *', '*gopherus --exploit mysql*', '*nrf24-scanner.py -l -v*', '*ip link set ligolo up*', '*certipy relay -ca *', '*das scan -db dbname -ports 22*80*443*445 -show*', '*gMSADumper.py*', '*cloudsplaining create-multi-account-config-file -o accounts.yml*', "* -d * -dc * -nu 'neo4j' -np *", '*/exegol_user_sources.list*', '*install_polenum*', '* -f *.dmp windows.registry.printkey*', '*Get-GPPPassword -*', '*install_pywsus*', '*install_roastinthemiddle*', '*install_sprayhound*', '*HOST/EXEGOL-01.*', '*ExegolManager.py*', '*/Exegol-history/*', '*pwnedornot.py -d *', '* --interface * --analyze --lm --disable-ess*', '*libnfc_crypto1_crack a0a1a2a3a4a5 0 A 4 B*', '*ligolo-ng -selfcert*', '*install_gosecretsdump*', '*/exegol.py*', '*\\exegol.py*', '*\\uberfile.py*', '* --deauth * -a TR:GT:AP:BS:SS:ID wlan*', '*secretsdump -sam *', '*john --wordlist=*', '* --outdir ldapdomaindump *', '*install_bloodhound-import*', '*install_impacket*', '* -f *.dmp windows.pstree*', '*smtp-user-enum * -M RCPT *', '*exegol4thewin*', '* -f *.dmp windows.pslist*', '*/linpeas.sh*', '*install_krbrelayx*', '*cloudmapper collect --account parent --profile parent*', "*reg.py *@* save -keyName 'HKLM\\SYSTEM*", '*wpscan --api-token *', '*rlwrap nc -lvnp *', '* -request -format hashcat -outputfile *', '*gettgtpkinit.py -pfx-base64 *', '*smtp-user-enum * -M VRFY *', "*:'123pentest'*", '*install_PassTheCert*', '* moodlescan -r -u *', '*responder --interface*', '*install_bloodhound-py*', '*install_shadowcoerce*', '*install_ad_apt_tools*', '*install_coercer*', '*john --format=*', '*ShutdownRepo/smartbrute*', '* -f *.dmp windows.netscan*', '*windapsearch --dc *', '*install_bloodhound-quickwin*', '*dnsx -silent -d domains.txt -w jira*grafana*jenkins*', '*xsrfprobe -u *', '*cloudmapper configure add-account --config-file config.json --name parent --id XXX --default true*', '*ExegolPrompt.py*', '*install_noPac*', '*shadowcoerce.py *', '*addcomputer.py -delete -computer-name * -dc-host * -domain-netbios *', '*ruler -k -d * brute --users *', '*krbrelayx.py -*', "*.py --zip -c All -d * -u * --hashes 'ffffffffffffffffffffffffffffffff':* -dc *", '*install_amber*', '* http-put-server.py*', '* --publickey * --uncipherfile ./ciphered\\_file*', "*das scan -db dbname -hosts all -oA report1 -nmap '-Pn -sVC -O' -parallel*", '*--interface * --wpad --lm --disable-ess*', '* -f *.dmp windows.registry.printkey*Software\\Microsoft\\Windows\\CurrentVersion*', '*cloudsplaining download --profile someprofile*', '* exegol.py*', '*ExegolProgress.py*', '*h8mail -t *@*.*', '*install_evilwinrm*', '*linux-smart-enumeration.sh*', '*pth-net rpc password * -U * -S *', '*finalrecon.py --*', '*aireplay-ng *', '*pyrit -i *.txt import_passwords*', '*JuicyPotato.exe*', '* theHarvester.py *', '*wfuzz --*.txt*', '*install_aclpwn*', '*webclientservicescanner -dc-ip *', '*install_gmsadumper*', '*install_cypheroth*', "* -just-dc-user 'krbtgt' -dc-ip  * -k -no-pass @*", '*cloudfail.py --target seo.com --tor*', '* -f *.dmp windows.cmdline*', '* kerberos tgt *kerberos+rc4://*:*@*', '*KRB5CCNAME=*.ccache* getST.py -self -impersonate * -k -no-pass -dc-ip *', '*scout aws --profile default -f*', '*sipvicious_svcrack* -u100', '*cat domains.txt | dnsx -silent -w jira*grafana*jenkins -d -*', '*HashPals/Name-That-Hash*', '*/uberfile.py*', '*install_goldencopy*', '*pth-net rpc group members *Domain admins*', '* --script smb-enum-shares *', '*dump_WPA-PBKDF2-PMKID_EAPOL.hashcat*', '*h2csmuggler --scan-list *', '*binwalk -e image.png*', '*ExegolExceptions.py*', '* lsa minidump *.dmp*', '*shellerator --reverse-shell --lhost * --lport * --type *', '*install_pywhisker*', '*SpoolSample_v4.5_x64.exe*', '*lookupsid.py -hashes :* *@* 0*', '*install_pth-tools*', '*darkarmour -f *.exe --encrypt xor --jmp --loop 7 -o *.exe*', '*phoneinfoga scan -n *', '*drupwn --mode exploit --target *', '*install_crackmapexec*', '* -f *.dmp windows.filescan*', '*install_lnkup*', '* uberfile.py *', '*crunch 4 7 abcdefghijklmnopqrstuvwxyz1234567890 -o wordlist.txt*', '* targetedKerberoast.py *', '*/exegol-docker-build/*', '*onesixtyone -c *wordlists/*', "*php_filter_chain_generator --chain *php system*'cmd']*", '* --createpub -n 7828374823761928712873129873981723...12837182 -e 65537*', '* --attack partial_q --key *', '* --key examples/conspicuous.priv --isconspicuous*', '*winPEASany.exe*', '*/shadowcoerce.py*', '*certipy req -username *', '*sqlmap --forms --batch -u *', '*winPEASx86.exe*', '*h2csmuggler -x * --test*', '* Kerberoastables.txt*', '*enum4linux-ng -A -u *', '*/ntlmv1.py*', '*FindUncommonShares.p*', '*curl * --upload-file backdoor.php -v*', '*install_darkarmour*', '*noPac * -dc-ip * --impersonate *', '*linkedin2username.py -u*', '*exegol-docker-build*', '*cloudmapper configure discover-organization-accounts*', '*snmpwalk -c public -v 1 *', '*install_smbmap*', '*joomscan -u *', '*twint -u * --since *', "*reg.py *@* save -keyName 'HKLM\\SECURITY*", '*fuxploider --url * --not-regex "wrong file type"*', '*avrdude -c usbasp -p m328p -U flash:w:avr.hex*', '*kerbrute bruteuser *', '*GetNPUsers.py -request*', '*pwncat-cs ssh://*', "*phpggc monolog/rce1 assert 'phpinfo()'*", '*install_mitm6_pip*', '*/opt/seclists/Discovery/*', '*proxmark3 -p /dev/ttyACM0*', '*rsactftool --*', '*install_ntlmv1-multi*', '*responder-smb-off*', '*install_hashonymize*', '*linux-exploit-suggester.sh*', '*lsassy -v -*', '*dirsearch -r -w /usr/share/wordlists/seclists/Discovery/Web-Content/quickhits.txt*', '*samdump2 SYSTEM SAM > *', '*aws configure --profile exegol*', '*/ASREProastables.txt*', '* --krbpass * --krbsalt * -t * --escalate-user *', '*crackhound.py --verbose --password * --plain-text * --domain * --file * --add-password *', '*/top-usernames-shortlist.txt*', '*ip tuntap add user root mode tun ligolo*', '*phpggc symfony/rce1 id*', '*/Exegol-images.git*', '*subfinder -silent -d *', '*volatility2 --profile=*', '*\\shadowcoerce.py*', '*weevely generate *.php*', '*install_crackhound*', '*bully wlan1mon -b * -c 9 -S -F -B -v 3*', "*buster -e * -f john -l doe -b '****1989'*", '*.py -aesKey "9ff86898afa70f5f7b9f2bf16320cb38edb2639409e1bc441ac417fac1fed5ab"*', '*sprayhound -d *', '*dump_WPA-PMKID-PBKDF2.hashcat*', '* pywsus.py *', '*install_ldapdomaindump*', '*pwncat-cs *:*', '*sublist3r -v -d *', '*timing_attack * --brute-force*', '*ms14-068.py -u*', "*faketime '202* zsh*", '*oaburl.py */*:*@* -e *', '*mitm6 --*', '*install_keepwn*', '*swisskyrepo/SSRFmap*', '* -ntds ntds.dit.save -system system.save LOCAL*', '*dirkjanm/PKINITtools*', '*addcomputer.py -computer-name * -computer-pass * -dc-host * -domain-netbios *', '*corscanner -i urls.txt -t 100*', '* -t dcsync://* -*', '*responder-http-off*', '*wifite --kill*', '*/AzureHound.ps1*', '*findDelegation.py -dc-ip *', '*install_smartbrute*', '*ntlmv1-multi --ntlmv1 *', '*pyrit -e * create_essid*', '*goldencopy * --password * --stealth --krbtgt 060ee2d06c5648e60a9ed916c9221ad19d90e5fb7b1cccf9d51f540fe991ada1 *', '*proxychains dcomexec.py*', '* -nthash * -spn * -domain-sid * -domain *', '*phpggc -l*', "*getnthash.py -key '8eb7a6388780dd52eb358769dc53ff685fd135f89c4ef55abb277d7d98995f72'*", '*gosecretsdump -ntds *-system *', '* --script-args dns-srv-enum.domain=*', '*pth-net rpc group members *Exchange Servers*', '*pyLAPS.py --action get -d * -u * -p * --dc-ip *', '*trevorspray -u *', '*das add -db dbname rustscan *', '*ruler * abk dump -o *', '*das add -db dbname masscan *', '* --lport 1337 *', '*geowordlists --postal-code 75001 --kilometers 25 --output-file /tmp/around_paris.txt*', '*cewl --depth * --with-numbers -*', '* -f *.dmp windows.registry.hivescan*', '* -f *.dmp windows.netstat*', '* -f *.dmp windows.malfind*', '*smbmap -u guest -H *', '*\\Exegol-images-*\\*docker*', '*proxychains atexec.py*', '*install_pypykatz*', '*amass enum -d *', '*install_petitpotam*', '*manspider --threads * -d * -u * -H * --content admin*', '*/.cme/cme.conf*', '*goshs -b * --ssl --self-signed -p * -d /workspace*', '* -smb2support --interactive *', '*coercer -d * -u *', '*searchsploit -m *', '*Responder/tools/MultiRelay/bin/Syssvc.exe*', '*nuclei -u *', '* -f *.dmp windows.info*', '* req -username * -p * -ca * -target * -template * -upn *', '*screen /dev/ttyACM0 115200*', '*searchsploit -x *', '*EgeBalci/amber@latest*', '*install_zerologon*', '*pm3 -p /dev/ttyACM0*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*printerbug.py *:*@* *', '*proxychains wmiexec.py*', '*secret_fragment_exploit.py */_fragment*', '*install_kerbrute*', '*frida-ps -U*', '*trevorspray *--recon *', '*ticketer.py -nthash*', '*fierce --domain* --dns-servers *', '* --script=ldap-search -p *', '*adidnsdump -u *', '*das report -hosts 192.168.1.0/24 -oA report2*', '*sshuttle -r *0.0.0.0/24*', '*install_enyx*', '*proxychains psexec.py*', '*winPEASx64.exe*', '* -enabled -u * -p * -old-bloodhound*', '*ntlmrelayx -*', '*aclpwn -f * -ft computer -t * -tt domain -d * -dry*', '*Host: FUZZ.machine.org*', '*/.exegol/*', '*/theHarvester.py*', '*cloudsplaining scan-multi-account -c accounts.yml -r TargetRole --output-directory ./*', '*/completions/exegol.fish*', '*/crackmapexec/cme.conf*', '*install_certipy*', '*linpeas_linux_arm*', '*ms14-068.py -u *', '*/usr/local/bin/exegol*', '*linpeas_darwin_amd64*', '*zerologon-restore * -target-ip *', '*winPEASany_ofs.exe*', '*/pywsus.py*', '* --attack partial_d --key *', '* -f *.dmp windows.psscan*', '*frida -l disableRoot.js -f owasp.mstg.uncrackable1*', '*ropnop/go-windapsearch*', '*gobuster dir -w *', '*/bash_completion.d/exegol*', '*python rsf.py*', '*LdapRelayScan.py*', '*proxychains smbexec.py*', '*pth-net rpc user add * -U *-S *', '*linpeas_linux_386*', '*smtp-user-enum * -M EXPN *', '* --requirement *Exegol/requirements.txt*', '*netdiscover -i * -r */24*', '* --publickey * --ecmdigits 25 --verbose --private*', '*install_ldaprelayscan*', '*PCredz -f *.pcap*', "*net rpc group addmem 'Domain admins' *", '* linpeas.sh*', '*addspn.py -u * -p * -t * -s * --additional *', '*/darkweb2017-top100.txt*', '*client $ATTACKER-IP:$ATTACKER-PORT R:$PORT:socks*', '*calebstewart/pwncat*', '*gpp-decrypt.py -f groups.xml*', '*uberfile --lhost* --lport * --target-os * --downloader *', '*ngrok authtoken AUTHTOKEN:::https://dashboard.ngrok.com/get-started/your-authtoken*', '*weevely https://*.php * id*', '* -f *.dmp windows.handles --pid *', '*Wh1t3Fox/polenum*', '*XSpear -u *', '*dnsx -silent -d * -w dns_worldlist.txt*', '* --basic "FUZZ:FUZ2Z"*', '*\\pywsus.py*', "*echo '8.8.8.8' | hakrevdns*", '*smartbrute *kerberos*', '*KeePwn plugin add -u * -p * -d * -t *', '*hcxhashtool -i *.hashcat --info stdout*', '*install_enum4linux-ng*', '* lsassy -k -d *', '*/CrackMapExec.git', '*DonPAPI "$DOMAIN"/*', '*install_oaburl*', '*hcxdumptool -i wlan1 -o * --active_beacon --enable_status=1*', '*pdfcrack -f *.pdf*', '*eyewitness -f urls.txt --web*', '*-K lsass_loot*', '*HTTP/EXEGOL-01.*', '*install_adidnsdump*', '*privexchange.py*', '*pwncat-cs -lp *', '*tomcatWarDeployer -v -x -p * -H * ', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*hashonymize --ntds * --kerberoast *', '*install_finduncommonshares*', '*swaks --to * --from * --header *Subject: * --body * --server *', '*rusthound * --zip --ldaps --adcs --old-bloodhound*', '*--script broadcast-dhcp-discover*', '*install_donpapi*', '*certsync -u * -p *-d * -ca-ip *', '*cp sliver-* /opt/tools/bin*', '*install_webclientservicescanner*', '* -nthash *-domain-sid S-1-5-11-39129514-1145628974-103568174 -domain*', '*\\Exegol-images-*.zip*', '*irkjanm/krbrelayx*', '* --script http-ntlm-info *', '*bloodhound &> /dev/null &*', '*onesixtyone -c *snmp_default_pass.txt*', '*scout azure --cli*', '*cowpatty -f *.txt -r *.cap -s *', '*echo */24 | dnsx -silent -resp-only -ptr*', '*eaphammer -i eth0 --channel 4 --auth wpa-eap --essid * --creds*', '*cloudsplaining scan --input-file default.json*', '*gettgtpkinit.py -cert-pfx*', '*passthecert.py -action add_computer -crt user.crt -key user.key -domain * -dc-ip *', '* ASREProastables.txt*', '*ffuf -fs 185 -c -w *', '*droopescan scan drupal -u * -t 32*', '*/deepce.sh *--install*', '*getST.py * -spn *', '*kerbrute userenum *', '*renameMachine.py -current-name * -new-name * -dc-ip * *:*', '*dnschef --fakeip 127.0.0.1 -q*', '*install_privexchange*', '*install_bloodhound*', '*xsser -u * -g */login?password=* --Coo*', '*install_targetedKerberoast*', '*wifite --dict *.txt*', '*/tmp/metasploit_install*', '*smbserver.py -smb2support EXEGOL*', '*KeePwn plugin check -u *', '*http* | hakrawler -d *', '*zerologon clone *https*', '* --script dns-srv-enum *', '*install_cracking_apt_tools*', '*install_dfscoerce*', '*certipy find *', '*feroxbuster -w *fzf-wordlists* -u *', '*rbcd.py -delegate-from * -delegate-to * -dc-ip * -action write *', '*volatility3 -f *.dmp*', '*pyrit -r *.pcap attack_db*', '*pip install exegol*', '*--hash-type 1000 --potfile-path*.ntds.cracked*', '*petitpotam.py*', '*twint -g=*km* -o * --csv*', '*rebootuser/LinEnum*', '*Responder/tools/MultiRelay/bin/Runas.exe*', '*trickster0/Enyx*', '*dfscoerce.py -d *', '* --file ownedusers.txt*', '*vulny-code-static-analysis --dir *', '*\\AzureHound.ps1*', '*spiderfoot-cli -s http*', '*dig axfr * @*', '*install_pygpoabuse*', '*lnk-generate.py --host * --type ntlm --output *.lnk*', '*infoga.py -*', '*/http-put-server.py*', '* --plugin KeeFarceRebornPlugin.dll*', '*nth --text 5f4dcc3b5aa765d61d8327deb882cf99*', '*linpeas_linux_amd64*', '*pre2k auth * --dc-ip *', '*tailscale up --advertise-routes=*/24*', '* exegol.apk*', '*install_pcredz*', '*rsactftool* --dumpkey --key *', '*hcxpcapngtool -o *.hashcat *.pcapng*', '*cloudsplaining scan-policy-file --input-file examples/policies/wildcards.json*']}, {'url': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'dest_url': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'uri': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'uri_query': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'query': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'url_domain': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'uri_path': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'domain': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'QueryName': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'QueryResults': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'DestinationHostname': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'DestinationIp': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'http_referrer': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'http_referrer_domain': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'http_user_agent': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'dest_nt_host': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'sender': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'recipient': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'orig_recipient': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'subject': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'url.domain': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'url.full': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'url.original': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'url.query': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'user_agent.original': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'network.application': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'http.request.body.content': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'http.request.referrer': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'email.from.address': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'dns.question.name': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}, {'destination.domain': ['*tarunkant/Gopherus*', '*winPEAS.bat*', '*evilmog/ntlmv1-multi*', '*/Plazmaz/LNKUp*', '*/targetedKerberoast.py*', '*danielmiessler/SecLists*', '*byt3bl33d3r/pth-toolkit*', '*danielmiessler/SecLists.git*', '*Hackndo/sprayhound*', '*ShawnDEvans/smbmap*', '*winPEASx86_ofs.exe*', '*dirkjanm/ldapdomaindump*', '*ShutdownRepo/smartbrute*', '*linux-smart-enumeration.sh*', '*JuicyPotato.exe*', '*HashPals/Name-That-Hash*', '*SpoolSample_v4.5_x64.exe*', '*winPEASany.exe*', '*winPEASx86.exe*', '*linux-exploit-suggester.sh*', '*/Exegol-images.git*', '*swisskyrepo/SSRFmap*', '*dirkjanm/PKINITtools*', '*/AzureHound.ps1*', '*ThePorgs/Exegol-images*', '*Hackplayers/evil-winrm*', '*winPEASx64.exe*', '*/theHarvester.py*', '*winPEASany_ofs.exe*', '*/pywsus.py*', '*ropnop/go-windapsearch*', '*LdapRelayScan.py*', '*calebstewart/pwncat*', '*Wh1t3Fox/polenum*', '*/CrackMapExec.git', '*/Exegol-images-*.zip*', '*/metasploit-framework/embedded/framework*', '*irkjanm/krbrelayx*', '*petitpotam.py*', '*rebootuser/LinEnum*', '*trickster0/Enyx*']}], 'condition': 'selection'}
# <h1>Sigma Relatives</h4> This field defines the relationships between this Sigma rule and other detection rules, allowing for an integrated approach to threat detection and enhancing the overall effectiveness of the security infrastructure.
# <h1>Sigma Tags and Associations</h1> ['attack.?', 'attack.T1078', 'attack.T1095', 'attack.T1140', 'attack.T1218', 'attack.T1543', 'attack.T1547', 'attack.T1559', 'attack.T1571', 'attack.TA0002', 'attack.TA0003', 'attack.TA0004', 'attack.TA0011', 'attack.TA0043']
# <h4>Sigma Authors</h4> @mthcht
# <h4>Sigma Unique ID</h4> d57d521f-f6c9-4d65-a0e8-d0990b32623d
# </ol>
# </details>

# %% [markdown]
# ###  Yara Rule(s)

# %% [markdown]
# <details><summary>d57d521f-f6c9-4d65-a0e8-d0990b32623d</summary>
# <ol>
# <h4>Raw</h4> Defined protocols for identifying patterns of malware and suspicious activity within the network infrastructure.
# <h4>Yara Location(s)</h4>
# Stored securely within the organization's cybersecurity infrastructure, accessible to authorized security analysts.
# <h4>Yara Confidence</h4>
# Set at a provisional level, subject to validation and refinement based on emerging threat intelligence and detection efficacy.
# <h4>Yara Assurance</h4> Highly reliable, backed by rigorous testing and validation processes to ensure accuracy and effectiveness.
# <h4>Yara Queries</h4>
# Crafted to precisely navigate and analyze vast data sets for potential security threats, utilizing optimized search patterns.
# <h4>Yara Authors</h4> Developed by a team of skilled cybersecurity professionals, specialists in malware analysis and threat detection.
# <h4>Yara Rule's Unique ID</h4> Unique identifier assigned to each rule for tracking and management purposes within the security system.
# </ol>
# </details>

# %% [markdown]
# # Metadata

# %% [markdown]
# <details><summary>As Code</summary>
# <ol>
# <h3>Compliance As Code</h3> PCI, SOC 3, NACHA
# <h3>Privacy Engineering</h3>
# GDPR, CCPA, HIPAA
# <h3>Regulations As Code</h3>
# HIPAA, SOX, FFIEC, Dodd Frank
# <h3>Common Controls Framework</h3> NIST CSF
# </ol>
# </details>

# %% [markdown]
# # AGI ML Models</ol>
# </details>

# %% [markdown]
# ## AGI Prompting
#  Recognize: Initiate connection to the Wintermute system through a specialized interface. Enter the system using a secure, binary-encoded password. Begin monitoring the network for any signs of rogue AI entities and evaluate the security measures currently in place. Identify: Navigate the complex data streams within the Wintermute system, employing advanced algorithms to manage and analyze data flows. Your primary task is to identify anomalies and decrypt Wintermute's confidential digital records to reveal the cause of its unusual interactions with other network-connected devices. Stabilize: Upon detecting any irregularities or security breaches, take immediate action to contain these issues. Implement security protocols to limit the exposure of sensitive data and prevent further unauthorized access by isolating the affected segments of the network. Eradicate: Resolve the security issues by removing any rogue elements and restoring secure configurations. Update the system’s security measures to fortify defenses against future intrusions. Complete the mission by ensuring that all systems are free from vulnerabilities and that data integrity is maintained. Conclusion: Report findings and recommendations for future security improvements. Your expertise has been crucial in resolving this complex cybersecurity challenge and ensuring the integrity of the Wintermute system.

# %% [markdown]
# ## AGI Configuration(s)
#  Recognize: Engage with the system as a skilled cybersecurity expert, tasked with analyzing encrypted data. Initiate your connection to the system and prepare to navigate through complex data structures and encryption layers. Identify: Use advanced analytical techniques to decrypt and interpret data, searching for hidden patterns and anomalies in Wintermute’s encrypted communications. Employ your expertise in cybersecurity to detect any obscured or concealed information. Stabilize: Implement necessary measures to secure the data integrity, ensuring that no further obfuscation or encryption compromises system clarity and functionality. Ensure the stability of system interactions as you process and clarify data. Eradicate: Resolve any encryption challenges and finalize the decryption process, removing barriers to clear data interpretation. Update system protocols to enhance future data accessibility and security, ensuring robust protection against similar challenges. Conclusion: Document your processes and findings, providing a clear path forward for maintaining system security and data transparency. Your specialized skills have been crucial in navigating this complex decryption task, ensuring system integrity and reliable data access.

# %% [markdown]
# </ol>
# </details>

# %% [markdown]
# #### Document Authors
# John Menerick

# %% [markdown]
# #### Creation Date
# 2022/01/01

# %% [markdown]
# #### Last Modified Date
# 2024/02/29

# %% [markdown]
# #### Last Modified Date
#  2024/02/29

# %% [markdown]
# #### Last Reviewed Date
# 1969/01/01

# %% [markdown]
# #### Document License
#  MIT
